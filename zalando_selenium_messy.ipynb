# %% [markdown]
# # Zalando scraper

# %%
## GOOD TO KNOW 

# website = https://zalando.nl/pre-owned-mode-heren/index.html
# article class = _0mW-4D _0xLoFW JT3_zV mo6ZnF _78xIQ- U4aOaA
# figure class = heWLCX
# tag product brand names = <span> 
# inspecting a product gives us: <a class="_LM JT3_zV CKDt_l CKDt_l LyRfpJ"href="https://www.zalando.nl/g-star-overhemd-blue-zir01hbly-001.html" rel="">

# %%
# Import packages
from bs4 import BeautifulSoup
import requests
import time 
from time import sleep
from datetime import datetime
import csv
import pandas as pd

# Make selenium and chromedriver work
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# %%
#debug = {'verbose': sys.stderr}
user_agent = {'User-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36 Edg/98.0.1108.62'}

# %%
# use webdriver.Chrome()
driver = webdriver.Chrome(ChromeDriverManager().install())

# run Zalando Pre-owned 
driver.get("https://www.zalando.nl/pre-owned-mode-heren/")
time.sleep(10)
print("done")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/sannevanettinger/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
# done

# %%
# accept button on the website (close pop-ups before proceeding)

driver.find_elements_by_class_name("uc-btn-primary")
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e028661ccdb13517ec011b102a9fb91e", element="d9e06a26-8896-45e5-8363-bba10c4da095")>]

# %%
# Create a function to collect all page urls
base_url = "https://www.zalando.nl/pre-owned-mode-heren/?p="
counter = 1

# Now create the function
def generate_page_urls(base_url, num_pages):
    page_urls = []
    
    for counter in range (1, num_pages + 1):
        full_url = base_url + str(counter) + "&order=activation_date"
        page_urls.append(full_url)
    
    return page_urls

# %%
page_urls = generate_page_urls(base_url, 2) 

generate_page_urls("https://www.zalando.nl/pre-owned-mode-heren/?p=", 20)
# Out:
# ['https://www.zalando.nl/pre-owned-mode-heren/?p=1&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=2&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=3&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=4&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=5&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=6&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=7&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=8&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=9&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=10&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=11&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=12&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=13&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=14&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=15&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=16&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=17&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=18&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=19&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=20&order=activation_date']

# %%
## cadeaubon is geen product 

from bs4 import BeautifulSoup
res = driver.page_source.encode('utf-8')
soup = BeautifulSoup(res, "html.parser")

# Create a function to collect the product_urls
def create_product_urls(page_urls):
    product_urls = []
    cnt=1
    for page_url in page_urls:
        cnt+=1
        driver.get(page_url)
        time.sleep(5)
        res = driver.page_source.encode('utf-8')
        soup = BeautifulSoup(res, "html.parser")
        #f=open('website_'+str(cnt)+'.html', 'w', encoding='utf-8')
        #f.write(res.text)
        #f.close()
        products = soup.find_all("div", class_= "DT5BTM w8MdNG cYylcv QylWsg _75qWlu iOzucJ JT3_zV DvypSJ")       
        print(len(products))
        sleep(1)

        for product in products:
            try:
                product_url = product.find("a").attrs["href"]
                print(product_url)
                product_urls.append(product_url)
            except:
                print("dit is geen product")
                
    return product_urls

# %%
product_urls = create_product_urls(page_urls)
len(product_urls)
# Out:
# 85
# https://www.zalando.nl/jack-and-jones-vest-dark-blue-zir01qbl8-001.html
# https://www.zalando.nl/jack-and-jones-sweater-met-rits-grey-zir01t66q-001.html
# https://www.zalando.nl/g-star-sweater-met-rits-grey-zir01t5tr-001.html
# https://www.zalando.nl/burton-sweater-met-rits-red-zir01sl2y-001.html
# https://www.zalando.nl/ben-sherman-vest-multi-colored-zir01qfya-001.html
# https://www.zalando.nl/g-star-straight-leg-jeans-blue-zir01shl0-001.html
# https://www.zalando.nl/mac-jeans-straight-leg-jeans-black-zir01s9f9-001.html
# https://www.zalando.nl/levis-slim-fit-jeans-blue-zir01sco8-001.html
# https://www.zalando.nl/carhartt-wip-broek-beige-zir00u02z-001.html
# https://www.zalando.nl/cadeaubonnen
# https://www.zalando.nl/lee-straight-leg-jeans-blue-zir01sk01-001.html
# https://www.zalando.nl/one-green-elephant-relaxed-fit-jeans-blue-zir01sjik-001.html
# https://www.zalando.nl/burton-broek-grey-zir01s8gr-001.html
# https://www.zalando.nl/armani-jeans-straight-leg-jeans-black-zir01s5sa-001.html
# https://www.zalando.nl/hilfiger-denim-straight-leg-jeans-orange-zir01sc3s-001.html
# https://www.zalando.nl/replay-straight-leg-jeans-blue-zir01sg2n-001.html
# https://www.zalando.nl/gardeur-broek-black-zir01rzaq-001.html
# https://www.zalando.nl/just-cavalli-slim-fit-jeans-blue-zir01sjlj-001.html
# https://www.zalando.nl/hudson-london-straight-leg-jeans-grey-zir01t5l6-001.html
# https://www.zalando.nl/camel-active-broek-grey-zir01t5sj-001.html
# https://www.zalando.nl/pme-legend-slim-fit-jeans-blue-zir01s7d5-001.html
html
# https://www.zalando.nl/polo-ralph-lauren-overhemd-blue-zir01shd5-001.html
# https://www.zalando.nl/armani-collezioni-zakelijk-overhemd-blue-zir01rzp4-001.html
# 170

# %%
import requests
from bs4 import BeautifulSoup

# scraping information from product pages

def get_product_pages(products):
    product_pages = []
    
    for url in product_urls: 
        res = requests.get(url, headers = user_agent)
        soup = BeautifulSoup(res.text, "html.parser")
        attributes = soup.find_all(class_="DT5BTM VHXqc_ rceRmQ _4NtqZU mIlIve")
        delivery = soup.find(class_="PBR5VH _0xLoFW EJ4MLB")
        prices = soup.find("div", class_="_0xLoFW vSgP6A _7ckuOK")
        
        for attribute in attributes:    
            product = attribute.find("h3", class_="mt1kvu ka2E9k uMhVZi FxZV-M SZKKsK pVrzNP _5Yd-hZ").text
            category = attribute.find("span", class_="EKabf7 R_QwOV").text
            size = attribute.find("span", class_="_7Cm1F9 ka2E9k uMhVZi dgII7d RYghuO pVrzNP").text
            delivery_time = delivery.find("span", class_="u-6V88 ka2E9k uMhVZi dgII7d RYghuO pVrzNP").text
            delivery_time = delivery_time.replace("werkdagen", "")
            delivery_time = delivery_time.replace(" ", "")
            
            try:
                price = prices.find("span", class_="pVrzNP").text
                price = price.replace(u'€\xa0', u' ')
                price = price.replace(" ", "")
            except:
                price = prices.find("span", class_="uqkIZw").text
                price = price.replace(u'€\xa0', u' ')
                price = price.replace(" ", "")

            product_pages.append({"url": url,
                                 "brand": product,
                                 "category": category,
                                 "price": price,
                                 "size": size,
                                 "delivery time": delivery_time})
   
    return product_pages
print("done")
# Out:
# done

# %%
product_attributes = get_product_pages(product_urls)

time.sleep(5)

product_attributes
# Out:
# [{'url': 'https://www.zalando.nl/jack-and-jones-vest-dark-blue-zir01qbl8-001.html',
#   'brand': 'Jack & Jones',
#   'category': 'Vest',
#   'price': '17,90',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-sweater-met-rits-grey-zir01t66q-001.html',
#   'brand': 'Jack & Jones',
#   'category': 'Sweater met rits',
#   'price': '14,20',
#   'size': 'M',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/g-star-sweater-met-rits-grey-zir01t5tr-001.html',
#   'brand': 'G-Star',
#   'category': 'Sweater met rits',
#   'price': '14,90',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/burton-sweater-met-rits-red-zir01sl2y-001.html',
#   'brand': 'Burton',
#   'category': 'Sweater met rits',
#   'price': '24,80',
#   'size': 'S',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/ben-sherman-vest-multi-colored-zir01qfya-001.html',
#   'brand': 'Ben Sherman',
#   'category': 'Vest',
#   'price': '18,90',
#   'size': 'M',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/g-star-straight-leg-jeans-blue-zir01shl0-001.html',
#   'brand': 'G-Star',
#   'category': 'Straight leg jeans',
#   'price': '21,90',
#   'size': '32x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/mac-jeans-straight-leg-jeans-black-zir01s9f9-001.html',
#   'brand': 'MAC Jeans',
#   'category': 'Straight leg jeans',
#   'price': '21,90',
#   'size': '34x30',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/levis-slim-fit-jeans-blue-zir01sco8-001.html',
#   'brand': "Levi's®",
#   'category': 'Slim fit jeans',
#   'price': '28,90',
#   'size': '31',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/carhartt-wip-broek-beige-zir00u02z-001.html',
#   'brand': 'Carhartt WIP',
#   'category': 'Broek',
#   'price': '20,90',
#   'size': '31x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/lee-straight-leg-jeans-blue-zir01sk01-001.html',
#   'brand': 'Lee',
#   'category': 'Straight leg jeans',
#   'price': '22,70',
#   'size': '32x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/one-green-elephant-relaxed-fit-jeans-blue-zir01sjik-001.html',
#   'brand': 'One Green Elephant',
#   'category': 'Relaxed fit jeans',
#   'price': '13,50',
#   'size': '33',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/burton-broek-grey-zir01s8gr-001.html',
#   'brand': 'Burton',
#   'category': 'Pantalon',
#   'price': '19,90',
#   'size': '36',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/armani-jeans-straight-leg-jeans-black-zir01s5sa-001.html',
#   'brand': 'Armani Jeans',
#   'category': 'Straight leg jeans',
#   'price': '50,90',
#   'size': '33',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/hilfiger-denim-straight-leg-jeans-orange-zir01sc3s-001.html',
#   'brand': 'Hilfiger Denim',
#   'category': 'Straight leg jeans',
#   'price': '24,90',
#   'size': '33',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/replay-straight-leg-jeans-blue-zir01sg2n-001.html',
#   'brand': 'Replay',
#   'category': 'Straight leg jeans',
#   'price': '61,90',
#   'size': '36',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gardeur-broek-black-zir01rzaq-001.html',
#   'brand': 'Gardeur',
#   'category': 'Broek',
#   'price': '21,90',
#   'size': '52',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/just-cavalli-slim-fit-jeans-blue-zir01sjlj-001.html',
#   'brand': 'Just Cavalli',
#   'category': 'Slim fit jeans',
#   'price': '73,40',
#   'size': '33',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/hudson-london-straight-leg-jeans-grey-zir01t5l6-001.html',
#   'brand': 'Hudson London',
#   'category': 'Straight leg jeans',
#   'price': '55,70',
#   'size': '26',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/camel-active-broek-grey-zir01t5sj-001.html',
#   'brand': 'camel active',
#   'category': 'Broek',
#   'price': '15,40',
#   'size': '34x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/pme-legend-slim-fit-jeans-blue-zir01s7d5-001.html',
#   'brand': 'PME Legend',
#   'category': 'Slim fit jeans',
#   'price': '28,90',
#   'size': '31x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/burton-straight-leg-jeans-blue-zir01sdl5-001.html',
#   'brand': 'Burton',
#   'category': 'Straight leg jeans',
#   'price': '15,90',
#   'size': '32x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gardeur-broek-grey-zir01s7wp-001.html',
#   'brand': 'Gardeur',
#   'category': 'Broek',
#   'price': '20,90',
#   'size': '40',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tommy-hilfiger-broek-beige-zir01skd5-001.html',
#   'brand': 'Tommy Hilfiger',
#   'category': 'Broek',
#   'price': '19,90',
#   'size': '32x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tiger-of-sweden-pantalon-brown-zir01sg0e-001.html',
#   'brand': 'Tiger of Sweden',
#   'category': 'Pantalon',
#   'price': '37,90',
#   'size': '46',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/nn07-broek-blue-zir01sl6g-001.html',
#   'brand': 'NN07',
#   'category': 'Broek',
#   'price': '25,20',
#   'size': '30x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tom-tailor-denim-chino-beige-zir01sf95-001.html',
#   'brand': 'TOM TAILOR DENIM',
#   'category': 'Chino',
#   'price': '17,90',
#   'size': '33x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gerry-weber-straight-leg-jeans-black-zir01sjeq-001.html',
#   'brand': 'Gerry Weber',
#   'category': 'Straight leg jeans',
#   'price': '17,90',
#   'size': '48',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gardeur-straight-leg-jeans-grey-zir01sbmf-001.html',
#   'brand': 'Gardeur',
#   'category': 'Straight leg jeans',
#   'price': '20,90',
#   'size': '50',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jlindeberg-slim-fit-jeans-grey-zir01s65u-001.html',
#   'brand': 'J.LINDEBERG',
#   'category': 'Slim fit jeans',
#   'price': '29,90',
#   'size': '31x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tom-tailor-denim-straight-leg-jeans-blue-zir01t5pk-001.html',
#   'brand': 'TOM TAILOR DENIM',
#   'category': 'Straight leg jeans',
#   'price': '13,40',
#   'size': '29x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gabba-straight-leg-jeans-blue-zir01s922-001.html',
#   'brand': 'Gabba',
#   'category': 'Straight leg jeans',
#   'price': '24,90',
#   'size': '33x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/hilfiger-denim-chino-brown-zir01sb64-001.html',
#   'brand': 'Hilfiger Denim',
#   'category': 'Chino',
#   'price': '18,90',
#   'size': '31',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/bonita-broek-black-zir01sjaj-001.html',
#   'brand': 'Bonita',
#   'category': 'Broek',
#   'price': '15,10',
#   'size': '40',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/boss-chino-black-zir01scfd-001.html',
#   'brand': 'BOSS',
#   'category': 'Chino',
#   'price': '28,90',
#   'size': '46',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/hilfiger-denim-straight-leg-jeans-blue-zir01s711-001.html',
#   'brand': 'Hilfiger Denim',
#   'category': 'Straight leg jeans',
#   'price': '24,90',
#   'size': '32x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/guru-jeans-tapered-fit-blue-zir01sf55-001.html',
#   'brand': 'Guru',
#   'category': 'Jeans Tapered Fit',
#   'price': '26,90',
#   'size': '48',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/brax-broek-yellow-zir01sbg8-001.html',
#   'brand': 'BRAX',
#   'category': 'Broek',
#   'price': '22,90',
#   'size': '58',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/aigner-broek-beige-zir01t56b-001.html',
#   'brand': 'AIGNER',
#   'category': 'Broek',
#   'price': '26,90',
#   'size': '52',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/meyer-pantalon-black-zir01sdx4-001.html',
#   'brand': 'Meyer',
#   'category': 'Pantalon',
#   'price': '22,90',
#   'size': '38',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/pierre-cardin-broek-beige-zir01rza0-001.html',
#   'brand': 'Pierre Cardin',
#   'category': 'Broek',
#   'price': '24,90',
#   'size': '36',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/brax-straight-leg-jeans-grey-zir01s9fa-001.html',
#   'brand': 'BRAX',
#   'category': 'Straight leg jeans',
#   'price': '22,90',
#   'size': '46',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tiger-of-sweden-chino-grey-zir01sk2v-001.html',
#   'brand': 'Tiger of Sweden',
#   'category': 'Chino',
#   'price': '51,80',
#   'size': '48',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/lee-straight-leg-jeans-grey-zir01sjaa-001.html',
#   'brand': 'Lee',
#   'category': 'Straight leg jeans',
#   'price': '23,90',
#   'size': '34x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/napapijri-broek-grey-zir01sde9-001.html',
#   'brand': 'Napapijri',
#   'category': 'Broek',
#   'price': '20,90',
#   'size': '36',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/pme-legend-broek-blue-zir01s7oa-001.html',
#   'brand': 'PME Legend',
#   'category': 'Broek',
#   'price': '39,90',
#   'size': '29x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/armani-exchange-straight-leg-jeans-blue-zir01scs4-001.html',
#   'brand': 'Armani Exchange',
#   'category': 'Straight leg jeans',
#   'price': '59,90',
#   'size': '32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gabba-broek-blue-zir01sk9r-001.html',
#   'brand': 'Gabba',
#   'category': 'Broek',
#   'price': '27,40',
#   'size': '30',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/g-star-slim-fit-jeans-blue-zir01slcf-001.html',
#   'brand': 'G-Star',
#   'category': 'Slim fit jeans',
#   'price': '17,90',
#   'size': '30x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/ben-sherman-broek-black-zir01sfw6-001.html',
#   'brand': 'Ben Sherman',
#   'category': 'Broek',
#   'price': '17,90',
#   'size': '42',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/oscar-jacobson-broek-blue-zir01s77f-001.html',
#   'brand': 'Oscar Jacobson',
#   'category': 'Pantalon',
#   'price': '20,90',
#   'size': '54',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/hugo-pantalon-black-zir01sdwy-001.html',
#   'brand': 'HUGO',
#   'category': 'Pantalon',
#   'price': '31,90',
#   'size': '35',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/nudie-jeans-broek-blue-zir01t05x-001.html',
#   'brand': 'Nudie Jeans',
#   'category': 'Broek',
#   'price': '20,70',
#   'size': '33x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/hope-chino-grey-zir01sb38-001.html',
#   'brand': 'Hope',
#   'category': 'Chino',
#   'price': '31,90',
#   'size': '46',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/garcia-straight-leg-jeans-blue-zir01sl31-001.html',
#   'brand': 'Garcia',
#   'category': 'Straight leg jeans',
#   'price': '15,90',
#   'size': '32x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/pierre-balmain-broek-grey-zir01rzat-001.html',
#   'brand': 'Pierre Balmain',
#   'category': 'Broek',
#   'price': '76,90',
#   'size': '36x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tommy-hilfiger-broek-blue-zir01sio5-001.html',
#   'brand': 'Tommy Hilfiger',
#   'category': 'Broek',
#   'price': '26,90',
#   'size': '48',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/nn07-broek-black-zir01sbka-001.html',
#   'brand': 'NN07',
#   'category': 'Broek',
#   'price': '34,90',
#   'size': '34x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/filippa-k-broek-blue-zir01sbeh-001.html',
#   'brand': 'Filippa K',
#   'category': 'Broek',
#   'price': '37,90',
#   'size': '52',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/levis-straight-leg-jeans-blue-zir01shoy-001.html',
#   'brand': "Levi's®",
#   'category': 'Straight leg jeans',
#   'price': '28,90',
#   'size': '29x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/bugatti-chino-brown-zir01sk7r-001.html',
#   'brand': 'Bugatti',
#   'category': 'Chino',
#   'price': '24,10',
#   'size': '33x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/polo-jeans-straight-leg-jeans-pink-zir01t5rh-001.html',
#   'brand': 'Polo Jeans',
#   'category': 'Straight leg jeans',
#   'price': '25,80',
#   'size': '32x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gabba-slim-fit-jeans-blue-zir01s9lt-001.html',
#   'brand': 'Gabba',
#   'category': 'Slim fit jeans',
#   'price': '25,90',
#   'size': '32x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/brax-broek-brown-zir01sguf-001.html',
#   'brand': 'BRAX',
#   'category': 'Broek',
#   'price': '26,90',
#   'size': '48x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/pierre-cardin-broek-black-zir01sfa8-001.html',
#   'brand': 'Pierre Cardin',
#   'category': 'Broek',
#   'price': '22,90',
#   'size': '34x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-straight-leg-jeans-blue-zir01t58d-001.html',
#   'brand': 'Jack & Jones',
#   'category': 'Straight leg jeans',
#   'price': '16,10',
#   'size': '28x30',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gap-chino-beige-zir01scau-001.html',
#   'brand': 'GAP',
#   'category': 'Chino',
#   'price': '15,90',
#   'size': '36x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/woodbird-broek-grey-zir01se5c-001.html',
#   'brand': 'Woodbird',
#   'category': 'Broek',
#   'price': '18,90',
#   'size': '29',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/levis-straight-leg-jeans-blue-zir01sjnk-001.html',
#   'brand': "Levi's®",
#   'category': 'Straight leg jeans',
#   'price': '20,90',
#   'size': '34x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/replay-straight-leg-jeans-blue-zir01rzfk-001.html',
#   'brand': 'Replay',
#   'category': 'Straight leg jeans',
#   'price': '61,90',
#   'size': '34x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-slim-fit-jeans-blue-zir01sgrc-001.html',
#   'brand': 'Jack & Jones',
#   'category': 'Slim fit jeans',
#   'price': '17,90',
#   'size': '29x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/diesel-straight-leg-jeans-blue-zir01sbg6-001.html',
#   'brand': 'Diesel',
#   'category': 'Straight leg jeans',
#   'price': '31,90',
#   'size': '34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/boss-broek-blue-zir01sbk7-001.html',
#   'brand': 'BOSS',
#   'category': 'Broek',
#   'price': '33,90',
#   'size': '24',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/timberland-broek-brown-zir01sgte-001.html',
#   'brand': 'Timberland',
#   'category': 'Broek',
#   'price': '21,90',
#   'size': '46',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/manuel-ritz-chino-brown-zir01slyr-001.html',
#   'brand': 'Manuel Ritz',
#   'category': 'Chino',
#   'price': '25,90',
#   'size': '33',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/lerros-slim-fit-jeans-grey-zir01siz9-001.html',
#   'brand': 'LERROS',
#   'category': 'Slim fit jeans',
#   'price': '16,60',
#   'size': '36x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/brax-broek-green-zir01sdxy-001.html',
#   'brand': 'BRAX',
#   'category': 'Broek',
#   'price': '24,90',
#   'size': '36x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/selected-homme-slim-fit-jeans-blue-zir01sjnr-001.html',
#   'brand': 'Selected Homme',
#   'category': 'Slim fit jeans',
#   'price': '16,70',
#   'size': '33x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/levis-straight-leg-jeans-blue-zir01scks-001.html',
#   'brand': "Levi's®",
#   'category': 'Straight leg jeans',
#   'price': '27,90',
#   'size': '36',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gerry-weber-broek-black-zir01s5mj-001.html',
#   'brand': 'Gerry Weber',
#   'category': 'Broek',
#   'price': '20,90',
#   'size': '42',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/brax-slim-fit-jeans-blue-zir01sdea-001.html',
#   'brand': 'BRAX',
#   'category': 'Slim fit jeans',
#   'price': '24,90',
#   'size': '28',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-slim-fit-jeans-blue-zir01s7pi-001.html',
#   'brand': 'Jack & Jones',
#   'category': 'Slim fit jeans',
#   'price': '17,90',
#   'size': '31x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/brax-broek-beige-zir01se5y-001.html',
#   'brand': 'BRAX',
#   'category': 'Broek',
#   'price': '26,90',
#   'size': '26',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/meyer-shorts-blue-zir01sdix-001.html',
#   'brand': 'Meyer',
#   'category': 'Shorts',
#   'price': '23,90',
#   'size': '46x30',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/ltb-bootcut-jeans-black-zir01sjgp-001.html',
#   'brand': 'LTB',
#   'category': 'Bootcut jeans',
#   'price': '18,30',
#   'size': '30',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/brax-broek-beige-zir01se5y-001.html',
#   'brand': 'BRAX',
#   'category': 'Broek',
#   'price': '26,90',
#   'size': '26',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/meyer-shorts-blue-zir01sdix-001.html',
#   'brand': 'Meyer',
#   'category': 'Shorts',
#   'price': '23,90',
#   'size': '46x30',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/ltb-bootcut-jeans-black-zir01sjgp-001.html',
#   'brand': 'LTB',
#   'category': 'Bootcut jeans',
#   'price': '18,30',
#   'size': '30',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-broek-beige-zir01s674-001.html',
#   'brand': 'Jack & Jones',
#   'category': 'Broek',
#   'price': '15,90',
#   'size': '32x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/nike-sportswear-trainingsbroek-grey-zir01sadr-001.html',
#   'brand': 'Nike Sportswear',
#   'category': 'Trainingsbroek',
#   'price': '16,90',
#   'size': 'S',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/nn07-straight-leg-jeans-blue-zir01scry-001.html',
#   'brand': 'NN07',
#   'category': 'Straight leg jeans',
#   'price': '34,90',
#   'size': '29x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/filippa-k-chino-black-zir01sgmk-001.html',
#   'brand': 'Filippa K',
#   'category': 'Chino',
#   'price': '31,90',
#   'size': 'S',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/g-star-slim-fit-jeans-blue-zir01sh8u-001.html',
#   'brand': 'G-Star',
#   'category': 'Slim fit jeans',
#   'price': '23,90',
#   'size': '31x30',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/meyer-chino-blue-zir01sdri-001.html',
#   'brand': 'Meyer',
#   'category': 'Chino',
#   'price': '22,90',
#   'size': '96',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/brax-straight-leg-jeans-black-zir01sfmh-001.html',
#   'brand': 'BRAX',
#   'category': 'Straight leg jeans',
#   'price': '27,90',
#   'size': '34x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/boss-chino-grey-zir01scjd-001.html',
#   'brand': 'BOSS',
#   'category': 'Chino',
#   'price': '28,90',
#   'size': '52',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/diesel-straight-leg-jeans-blue-zir01scsv-001.html',
#   'brand': 'Diesel',
#   'category': 'Straight leg jeans',
#   'price': '32,90',
#   'size': '34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-chino-beige-zir01t4sm-001.html',
#   'brand': 'Jack & Jones',
#   'category': 'Chino',
#   'price': '12,20',
#   'size': '36x36',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/mac-jeans-straight-leg-jeans-blue-zir01senw-001.html',
#   'brand': 'MAC Jeans',
#   'category': 'Straight leg jeans',
#   'price': '18,90',
#   'size': '44x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/levis-straight-leg-jeans-blue-zir01si3x-001.html',
#   'brand': "Levi's®",
#   'category': 'Straight leg jeans',
#   'price': '28,90',
#   'size': '32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/adidas-slvr-trainingsbroek-black-zir01sde2-001.html',
#   'brand': 'adidas SLVR',
#   'category': 'Trainingsbroek',
#   'price': '15,90',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/brax-broek-green-zir01sfaa-001.html',
#   'brand': 'BRAX',
#   'category': 'Broek',
#   'price': '25,90',
#   'size': '48x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/marc-opolo-broek-green-zir01sjjk-001.html',
#   'brand': "Marc O'Polo",
#   'category': 'Broek',
#   'price': '12,50',
#   'size': '48',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gant-straight-leg-jeans-black-zir01scus-001.html',
#   'brand': 'GANT',
#   'category': 'Straight leg jeans',
#   'price': '22,90',
#   'size': '33x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/levis-made-and-crafted-straight-leg-jeans-black-zir01sght-001.html',
#   'brand': "Levi's® Made & Crafted",
#   'category': 'Straight leg jeans',
#   'price': '37,90',
#   'size': 'M',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gant-slim-fit-jeans-blue-zir01sfiv-001.html',
#   'brand': 'GANT',
#   'category': 'Slim fit jeans',
#   'price': '22,90',
#   'size': '31',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/mac-jeans-relaxed-fit-jeans-beige-zir01sct9-001.html',
#   'brand': 'MAC Jeans',
#   'category': 'Relaxed fit jeans',
#   'price': '22,90',
#   'size': '40x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/mustang-slim-fit-jeans-blue-zir01sk3s-001.html',
#   'brand': 'Mustang',
#   'category': 'Slim fit jeans',
#   'price': '25,20',
#   'size': '29x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/cos-broek-beige-zir01sci3-001.html',
#   'brand': 'COS',
#   'category': 'Broek',
#   'price': '18,90',
#   'size': '50',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/calvin-klein-slim-fit-jeans-blue-zir01t0g3-001.html',
#   'brand': 'Calvin Klein',
#   'category': 'Slim fit jeans',
#   'price': '27,20',
#   'size': '34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/meyer-broek-brown-zir01skro-001.html',
#   'brand': 'Meyer',
#   'category': 'Broek',
#   'price': '22,90',
#   'size': '46',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/trussardi-broek-grey-zir01s9h7-001.html',
#   'brand': 'Trussardi',
#   'category': 'Broek',
#   'price': '36,90',
#   'size': '36x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tom-tailor-broek-beige-zir01siba-001.html',
#   'brand': 'TOM TAILOR',
#   'category': 'Broek',
#   'price': '16,90',
#   'size': '36',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/guess-straight-leg-jeans-blue-zir01sea2-001.html',
#   'brand': 'Guess',
#   'category': 'Straight leg jeans',
#   'price': '19,90',
#   'size': '30',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/mac-jeans-broek-brown-zir01sgj9-001.html',
#   'brand': 'MAC Jeans',
#   'category': 'Broek',
#   'price': '20,90',
#   'size': '46',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/armani-jeans-broek-grey-zir01scre-001.html',
#   'brand': 'Armani Jeans',
#   'category': 'Broek',
#   'price': '32,90',
#   'size': '106',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/oneill-broek-beige-zir01sfz6-001.html',
#   'brand': "O'Neill",
#   'category': 'Broek',
#   'price': '16,90',
#   'size': '34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/diesel-slim-fit-jeans-black-zir01s9fo-001.html',
#   'brand': 'Diesel',
#   'category': 'Slim fit jeans',
#   'price': '32,90',
#   'size': '29',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tiger-of-sweden-chino-blue-zir01sc54-001.html',
#   'brand': 'Tiger of Sweden',
#   'category': 'Chino',
#   'price': '35,90',
#   'size': '54',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/meyer-broek-pink-zir01sf2b-001.html',
#   'brand': 'Meyer',
#   'category': 'Broek',
#   'price': '22,90',
#   'size': '38x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/esprit-collection-chino-black-zir01sd75-001.html',
#   'brand': 'Esprit Collection',
#   'category': 'Chino',
#   'price': '15,90',
#   'size': '48',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gant-broek-brown-zir01sbf3-001.html',
#   'brand': 'GANT',
#   'category': 'Broek',
#   'price': '23,90',
#   'size': '32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/brax-broek-brown-zir01sdin-001.html',
#   'brand': 'BRAX',
#   'category': 'Broek',
#   'price': '24,90',
#   'size': '34x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/selected-homme-chino-brown-zir01sjgf-001.html',
#   'brand': 'Selected Homme',
#   'category': 'Chino',
#   'price': '14,30',
#   'size': '36x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-cargobroek-grey-zir01sjbg-001.html',
#   'brand': 'Jack & Jones',
#   'category': 'Cargobroek',
#   'price': '18,60',
#   'size': '28x30',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/diesel-straight-leg-jeans-blue-zir01slc6-001.html',
#   'brand': 'Diesel',
#   'category': 'Straight leg jeans',
#   'price': '17,70',
#   'size': '36',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/drykorn-broek-beige-zir01sk5b-001.html',
#   'brand': 'DRYKORN',
#   'category': 'Broek',
#   'price': '13,40',
#   'size': '36x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/hugo-chino-black-zir01si8n-001.html',
#   'brand': 'HUGO',
#   'category': 'Broek',
#   'price': '33,90',
#   'size': '56',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/boss-chino-green-zir01sb62-001.html',
#   'brand': 'BOSS',
#   'category': 'Chino',
#   'price': '28,90',
#   'size': '48',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/scotch-and-soda-shorts-brown-zir01skvj-001.html',
#   'brand': 'Scotch & Soda',
#   'category': 'Shorts',
#   'price': '16,90',
#   'size': '32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/replay-straight-leg-jeans-blue-zir01scxc-001.html',
#   'brand': 'Replay',
#   'category': 'Straight leg jeans',
#   'price': '74,90',
#   'size': '32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/bruun-and-stengade-broek-grey-zir01slb8-001.html',
#   'brand': 'Bruun & Stengade',
#   'category': 'Broek',
#   'price': '17,90',
#   'size': '34x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/mavi-broek-black-zir01s8gn-001.html',
#   'brand': 'Mavi',
#   'category': 'Broek',
#   'price': '19,90',
#   'size': '30x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/nudie-jeans-slim-fit-jeans-blue-zir01sejc-001.html',
#   'brand': 'Nudie Jeans',
#   'category': 'Slim fit jeans',
#   'price': '27,90',
#   'size': '33x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/next-zakelijk-overhemd-blue-zir01s8y6-001.html',
#   'brand': 'Next',
#   'category': 'Zakelijk overhemd',
#   'price': '16,90',
#   'size': '41',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/reiss-overhemd-grey-zir01sdgf-001.html',
#   'brand': 'Reiss',
#   'category': 'Overhemd',
#   'price': '28,90',
#   'size': 'XL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/marks-and-spencer-overhemd-blue-zir01sd26-001.html',
#   'brand': 'Marks & Spencer',
#   'category': 'Overhemd',
#   'price': '15,90',
#   'size': '39',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/markus-lupfer-t-shirt-basic-purple-zir01s6gf-001.html',
#   'brand': 'Markus Lupfer',
#   'category': 'T-shirt basic',
#   'price': '40,90',
#   'size': '48',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/marks-and-spencer-overhemd-red-zir01seeu-001.html',
#   'brand': 'Marks & Spencer',
#   'category': 'Overhemd',
#   'price': '16,90',
#   'size': '40',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/french-connection-overhemd-black-zir01s9ap-001.html',
#   'brand': 'French Connection',
#   'category': 'Overhemd',
#   'price': '15,90',
#   'size': 'XXL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/marks-and-spencer-overhemd-blue-zir01sgm6-001.html',
#   'brand': 'Marks & Spencer',
#   'category': 'Overhemd',
#   'price': '16,90',
#   'size': '42',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/ted-baker-overhemd-blue-zir01s7iz-001.html',
#   'brand': 'Ted Baker',
#   'category': 'Overhemd',
#   'price': '27,90',
#   'size': '40',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/scotch-and-soda-overhemd-blue-zir01s9ne-001.html',
#   'brand': 'Scotch & Soda',
#   'category': 'Overhemd',
#   'price': '18,90',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/ben-sherman-overhemd-red-zir01sde1-001.html',
#   'brand': 'Ben Sherman',
#   'category': 'Overhemd',
#   'price': '17,90',
#   'size': 'XL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tommy-hilfiger-zakelijk-overhemd-black-zir01s3pm-001.html',
#   'brand': 'Tommy Hilfiger',
#   'category': 'Zakelijk overhemd',
#   'price': '25,90',
#   'size': 'S',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tommy-hilfiger-overhemd-blue-zir01sgs0-001.html',
#   'brand': 'Tommy Hilfiger',
#   'category': 'Overhemd',
#   'price': '24,90',
#   'size': 'S',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/selected-homme-overhemd-blue-zir01s8w3-001.html',
#   'brand': 'Selected Homme',
#   'category': 'Overhemd',
#   'price': '15,90',
#   'size': 'S',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/wolsey-overhemd-yellow-zir01sf9g-001.html',
#   'brand': 'Wolsey',
#   'category': 'Overhemd',
#   'price': '18,90',
#   'size': 'XXL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/selected-homme-overhemd-green-zir01sdbr-001.html',
#   'brand': 'Selected Homme',
#   'category': 'Overhemd',
#   'price': '16,90',
#   'size': 'XL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/selected-homme-overhemd-blue-zir01saor-001.html',
#   'brand': 'Selected Homme',
#   'category': 'Overhemd',
#   'price': '15,90',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/marks-and-spencer-overhemd-blue-zir01sg5r-001.html',
#   'brand': 'Marks & Spencer',
#   'category': 'Overhemd',
#   'price': '15,90',
#   'size': 'XL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/marks-and-spencer-overhemd-grey-zir01sa8k-001.html',
#   'brand': 'Marks & Spencer',
#   'category': 'Overhemd',
#   'price': '15,90',
#   'size': '37',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/brax-overhemd-blue-zir01sj5f-001.html',
#   'brand': 'BRAX',
#   'category': 'Overhemd',
#   'price': '14,00',
#   'size': 'XL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/olymp-level-five-zakelijk-overhemd-orange-zir01s9q5-001.html',
#   'brand': 'OLYMP Level Five',
#   'category': 'Zakelijk overhemd',
#   'price': '16,90',
#   'size': '38',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/olymp-overhemd-grey-zir01s9mq-001.html',
#   'brand': 'OLYMP',
#   'category': 'Overhemd',
#   'price': '27,90',
#   'size': '39',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/hugo-overhemd-purple-zir01sjte-001.html',
#   'brand': 'HUGO',
#   'category': 'Overhemd',
#   'price': '30,20',
#   'size': 'M',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/g-star-overhemd-blue-zir01sivh-001.html',
#   'brand': 'G-Star',
#   'category': 'Overhemd',
#   'price': '16,70',
#   'size': 'M',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/hkt-by-hackett-overhemd-blue-zir01sdkp-001.html',
#   'brand': 'HKT by Hackett',
#   'category': 'Overhemd',
#   'price': '22,90',
#   'size': 'XL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gant-overhemd-green-zir01sel0-001.html',
#   'brand': 'GANT',
#   'category': 'Overhemd',
#   'price': '22,90',
#   'size': 'XXL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/suit-overhemd-beige-zir01sj43-001.html',
#   'brand': 'Suit',
#   'category': 'Overhemd',
#   'price': '12,30',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/eterna-overhemd-black-zir01seko-001.html',
#   'brand': 'Eterna',
#   'category': 'Overhemd',
#   'price': '17,90',
#   'size': '46',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/marks-and-spencer-overhemd-blue-zir01s7p1-001.html',
#   'brand': 'Marks & Spencer',
#   'category': 'Overhemd',
#   'price': '15,90',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/next-overhemd-grey-zir01sacz-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '15,90',
#   'size': 'XL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/eterna-zakelijk-overhemd-blue-zir01s9rq-001.html',
#   'brand': 'Eterna',
#   'category': 'Zakelijk overhemd',
#   'price': '16,90',
#   'size': '39',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/next-overhemd-purple-zir01sc8u-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '15,90',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-overhemd-blue-zir01s9s2-001.html',
#   'brand': 'Jack & Jones',
#   'category': 'Overhemd',
#   'price': '15,90',
#   'size': '44',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/superdry-overhemd-blue-zir01sgib-001.html',
#   'brand': 'Superdry',
#   'category': 'Overhemd',
#   'price': '19,90',
#   'size': 'XS',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/polo-ralph-lauren-overhemd-blue-zir01shd5-001.html',
#   'brand': 'Polo Ralph Lauren',
#   'category': 'Overhemd',
#   'price': '32,90',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/armani-collezioni-zakelijk-overhemd-blue-zir01rzp4-001.html',
#   'brand': 'Armani Collezioni',
#   'category': 'Zakelijk overhemd',
#   'price': '44,90',
#   'size': '41',
#   'delivery time': '3-6'}]

# %%
now = datetime.now()
print(now)
# Out:
# 2022-03-16 13:48:37.515949

# %%
import csv 

with open("product_description_pre_owned.csv", "w", encoding = 'utf-8', newline='') as csv_file: 
    writer = csv.writer(csv_file, delimiter = ";")
    writer.writerow(["url", "brand", "category", "price", "size", "delivery time", "now"])
    now = datetime.now()
    for product in product_attributes: 
        writer.writerow([product['url'], product['brand'], product['category'], product['price'], product['size'], product['delivery time'], now])
print('done!')
# Out:
# done!
