# %% [markdown]
# # Zalando scraper | Pre-owned heren

# %%
## GOOD TO KNOW 

# website = https://zalando.nl/pre-owned-mode-heren/index.html
# article class = _0mW-4D _0xLoFW JT3_zV mo6ZnF _78xIQ- U4aOaA
# figure class = heWLCX
# tag product brand names = <span> 
# inspecting a product gives us: <a class="_LM JT3_zV CKDt_l CKDt_l LyRfpJ"href="https://www.zalando.nl/g-star-overhemd-blue-zir01hbly-001.html" rel="">

# %%
# Import packages
from bs4 import BeautifulSoup
import requests
import time 
from time import sleep
from datetime import datetime
import csv
import pandas as pd

# Make selenium and chromedriver work
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# %%
#debug = {'verbose': sys.stderr}
user_agent = {'User-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36 Edg/98.0.1108.62'}

# %%
# use webdriver.Chrome()
driver = webdriver.Chrome(ChromeDriverManager().install())

# run Zalando Pre-owned 
driver.get("https://www.zalando.nl/pre-owned-mode-heren/")
time.sleep(10)
print("done")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/jurg/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
# /var/folders/p0/r_tdscqn23546rkg5ldzxc180000gn/T/ipykernel_4344/1669193487.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# done

# %%
# accept button on the website (close pop-ups before proceeding)

driver.find_elements_by_class_name("uc-btn-primary")
# Out:
# /var/folders/p0/r_tdscqn23546rkg5ldzxc180000gn/T/ipykernel_4344/131874113.py:3: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   driver.find_elements_by_class_name("uc-btn-primary")
# [<selenium.webdriver.remote.webelement.WebElement (session="8990e103ed78c7ca7026179af61ce835", element="7a707fec-829c-4814-a426-c2c75ab6169f")>]

# %%
# Create a function to collect all page urls
base_url = "https://www.zalando.nl/pre-owned-mode-heren/?p="
counter = 1

# Now create the function
def generate_page_urls(base_url, num_pages):
    page_urls = []
    
    for counter in range (1, num_pages + 1):
        full_url = base_url + str(counter) + "&order=activation_date"
        page_urls.append(full_url)
    
    return page_urls

# %%
page_urls = generate_page_urls(base_url, 2) 

generate_page_urls("https://www.zalando.nl/pre-owned-mode-heren/?p=", 20)
# Out:
# ['https://www.zalando.nl/pre-owned-mode-heren/?p=1&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=2&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=3&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=4&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=5&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=6&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=7&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=8&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=9&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=10&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=11&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=12&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=13&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=14&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=15&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=16&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=17&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=18&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=19&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=20&order=activation_date']

# %%
## cadeaubon is geen product 

from bs4 import BeautifulSoup
res = driver.page_source.encode('utf-8')
soup = BeautifulSoup(res, "html.parser")

# Create a function to collect the product_urls
def create_product_urls(page_urls):
    product_urls = []
    cnt=1
    for page_url in page_urls:
        cnt+=1
        driver.get(page_url)
        time.sleep(5)
        res = driver.page_source.encode('utf-8')
        soup = BeautifulSoup(res, "html.parser")
        #f=open('website_'+str(cnt)+'.html', 'w', encoding='utf-8')
        #f.write(res.text)
        #f.close()
        products = soup.find_all("div", class_= "DT5BTM w8MdNG cYylcv QylWsg _75qWlu iOzucJ JT3_zV DvypSJ")       
        print(len(products))
        sleep(1)

        for product in products:
            try:
                product_url = product.find("a").attrs["href"]
                print(product_url)
                product_urls.append(product_url)
            except:
                print("dit is geen product")
                
    return product_urls

# %%
product_urls = create_product_urls(page_urls)
len(product_urls)
# Out:
# 84
# https://www.zalando.nl/next-overhemd-grey-zir01skse-001.html
# https://www.zalando.nl/tiger-of-sweden-overhemd-blue-zir01sgz2-001.html
# https://www.zalando.nl/hollister-co-overhemd-blue-zir01sixj-001.html
# https://www.zalando.nl/marks-and-spencer-overhemd-pink-zir01seze-001.html
# https://www.zalando.nl/gardeur-broek-black-zir01rzaq-001.html
# https://www.zalando.nl/armani-exchange-straight-leg-jeans-blue-zir01scs4-001.html
# https://www.zalando.nl/boss-chino-black-zir01sfxl-001.html
# https://www.zalando.nl/selected-homme-chino-brown-zir01se4d-001.html
# https://www.zalando.nl/hudson-london-straight-leg-jeans-grey-zir01t5l6-001.html
# https://www.zalando.nl/brax-broek-sand-zir01sg9b-001.html
# https://www.zalando.nl/tommy-hilfiger-broek-beige-zir01skd5-001.html
# https://www.zalando.nl/brax-broek-beige-zir01scd5-001.html
# https://www.zalando.nl/bogner-straight-leg-jeans-blue-zir01s7gl-001.html
# https://www.zalando.nl/bruun-and-stengade-broek-grey-zir01slb8-001.html
# https://www.zalando.nl/jlindeberg-slim-fit-jeans-grey-zir01s65u-001.html
# https://www.zalando.nl/mac-jeans-broek-brown-zir01sgj9-001.html
# https://www.zalando.nl/diesel-slim-fit-jeans-black-zir01s9fo-001.html
# https://www.zalando.nl/meyer-broek-pink-zir01sf2b-001.html
001.html
# https://www.zalando.nl/next-overhemd-blue-zir01s003-001.html
# https://www.zalando.nl/sand-copenhagen-overhemd-multi-colored-zir01puku-001.html
# https://www.zalando.nl/eterna-overhemd-blue-zir01sdxa-001.html
# https://www.zalando.nl/eterna-overhemd-blue-zir01se6a-001.html
# https://www.zalando.nl/superdry-overhemd-blue-zir01sjxt-001.html
# https://www.zalando.nl/tom-tailor-overhemd-green-zir01szxr-001.html
# https://www.zalando.nl/calvin-klein-jeans-overhemd-grey-zir01t0qt-001.html
# https://www.zalando.nl/seidensticker-overhemd-red-zir01t0k5-001.html
# https://www.zalando.nl/jack-and-jones-overhemd-black-zir01sj8o-001.html
# https://www.zalando.nl/camel-active-overhemd-green-zir01skog-001.html
# https://www.zalando.nl/gap-overhemd-blue-zir01sjvw-001.html
# 168

# %%
import requests
from bs4 import BeautifulSoup

# scraping information from product pages

def get_product_pages(products):
    product_pages = []
    
    for url in product_urls: 
        res = requests.get(url, headers = user_agent)
        soup = BeautifulSoup(res.text, "html.parser")
        attributes = soup.find_all(class_="DT5BTM VHXqc_ rceRmQ _4NtqZU mIlIve")
        delivery = soup.find(class_="PBR5VH _0xLoFW EJ4MLB")
        prices = soup.find("div", class_="_0xLoFW vSgP6A _7ckuOK")
        
        for attribute in attributes:    
            product = attribute.find("h3", class_="mt1kvu ka2E9k uMhVZi FxZV-M SZKKsK pVrzNP _5Yd-hZ").text
            category = attribute.find("span", class_="EKabf7 R_QwOV").text
            size = attribute.find("span", class_="_7Cm1F9 ka2E9k uMhVZi dgII7d RYghuO pVrzNP").text
            delivery_time = delivery.find("span", class_="u-6V88 ka2E9k uMhVZi dgII7d RYghuO pVrzNP").text
            delivery_time = delivery_time.replace("werkdagen", "")
            delivery_time = delivery_time.replace(" ", "")
            
            try:
                price = prices.find("span", class_="pVrzNP").text
                price = price.replace(u'€\xa0', u' ')
                price = price.replace(" ", "")
            except:
                price = prices.find("span", class_="uqkIZw").text
                price = price.replace(u'€\xa0', u' ')
                price = price.replace(" ", "")

            product_pages.append({"url": url,
                                 "brand": product,
                                 "category": category,
                                 "price": price,
                                 "size": size,
                                 "delivery time": delivery_time})
   
    return product_pages
print("done")
# Out:
# done

# %%
product_attributes = get_product_pages(product_urls)

time.sleep(5)

product_attributes
# Out:
# [{'url': 'https://www.zalando.nl/next-overhemd-grey-zir01skse-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '16,40',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tiger-of-sweden-overhemd-blue-zir01sgz2-001.html',
#   'brand': 'Tiger of Sweden',
#   'category': 'Overhemd',
#   'price': '26,90',
#   'size': '41',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/hollister-co-overhemd-blue-zir01sixj-001.html',
#   'brand': 'Hollister Co.',
#   'category': 'Overhemd',
#   'price': '12,30',
#   'size': 'XL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/marks-and-spencer-overhemd-pink-zir01seze-001.html',
#   'brand': 'Marks & Spencer',
#   'category': 'Overhemd',
#   'price': '17,90',
#   'size': 'M',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gardeur-broek-black-zir01rzaq-001.html',
#   'brand': 'Gardeur',
#   'category': 'Broek',
#   'price': '21,90',
#   'size': '52',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/armani-exchange-straight-leg-jeans-blue-zir01scs4-001.html',
#   'brand': 'Armani Exchange',
#   'category': 'Straight leg jeans',
#   'price': '62,90',
#   'size': '32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/boss-chino-black-zir01sfxl-001.html',
#   'brand': 'BOSS',
#   'category': 'Chino',
#   'price': '28,90',
#   'size': '34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/selected-homme-chino-brown-zir01se4d-001.html',
#   'brand': 'Selected Homme',
#   'category': 'Chino',
#   'price': '19,90',
#   'size': '31x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/hudson-london-straight-leg-jeans-grey-zir01t5l6-001.html',
#   'brand': 'Hudson London',
#   'category': 'Straight leg jeans',
#   'price': '55,70',
#   'size': '26',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/brax-broek-sand-zir01sg9b-001.html',
#   'brand': 'BRAX',
#   'category': 'Broek',
#   'price': '29,90',
#   'size': '46',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tommy-hilfiger-broek-beige-zir01skd5-001.html',
#   'brand': 'Tommy Hilfiger',
#   'category': 'Broek',
#   'price': '22,90',
#   'size': '32x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/brax-broek-beige-zir01scd5-001.html',
#   'brand': 'BRAX',
#   'category': 'Broek',
#   'price': '29,90',
#   'size': '54',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/bogner-straight-leg-jeans-blue-zir01s7gl-001.html',
#   'brand': 'Bogner',
#   'category': 'Straight leg jeans',
#   'price': '36,90',
#   'size': '54',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/bruun-and-stengade-broek-grey-zir01slb8-001.html',
#   'brand': 'Bruun & Stengade',
#   'category': 'Broek',
#   'price': '17,90',
#   'size': '34x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jlindeberg-slim-fit-jeans-grey-zir01s65u-001.html',
#   'brand': 'J.LINDEBERG',
#   'category': 'Slim fit jeans',
#   'price': '29,90',
#   'size': '31x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/mac-jeans-broek-brown-zir01sgj9-001.html',
#   'brand': 'MAC Jeans',
#   'category': 'Broek',
#   'price': '20,90',
#   'size': '46',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/diesel-slim-fit-jeans-black-zir01s9fo-001.html',
#   'brand': 'Diesel',
#   'category': 'Slim fit jeans',
#   'price': '32,90',
#   'size': '29',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/meyer-broek-pink-zir01sf2b-001.html',
#   'brand': 'Meyer',
#   'category': 'Broek',
#   'price': '22,90',
#   'size': '38x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/esprit-collection-chino-black-zir01sd75-001.html',
#   'brand': 'Esprit Collection',
#   'category': 'Chino',
#   'price': '15,90',
#   'size': '48',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tom-tailor-denim-straight-leg-jeans-blue-zir01t5pk-001.html',
#   'brand': 'TOM TAILOR DENIM',
#   'category': 'Straight leg jeans',
#   'price': '13,40',
#   'size': '29x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gant-broek-brown-zir01sbf3-001.html',
#   'brand': 'GANT',
#   'category': 'Broek',
#   'price': '23,90',
#   'size': '32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/selected-homme-chino-brown-zir01sjgf-001.html',
#   'brand': 'Selected Homme',
#   'category': 'Chino',
#   'price': '14,30',
#   'size': '36x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-cargobroek-grey-zir01sjbg-001.html',
#   'brand': 'Jack & Jones',
#   'category': 'Cargobroek',
#   'price': '18,60',
#   'size': '28x30',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/mavi-broek-black-zir01s8gn-001.html',
#   'brand': 'Mavi',
#   'category': 'Broek',
#   'price': '19,90',
#   'size': '30x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/boss-chino-green-zir01sb62-001.html',
#   'brand': 'BOSS',
#   'category': 'Chino',
#   'price': '28,90',
#   'size': '48',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/scotch-and-soda-shorts-brown-zir01skvj-001.html',
#   'brand': 'Scotch & Soda',
#   'category': 'Shorts',
#   'price': '16,90',
#   'size': '32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/bonita-broek-black-zir01sjaj-001.html',
#   'brand': 'Bonita',
#   'category': 'Broek',
#   'price': '15,10',
#   'size': '40',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/boss-chino-black-zir01scfd-001.html',
#   'brand': 'BOSS',
#   'category': 'Chino',
#   'price': '28,90',
#   'size': '46',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/guru-jeans-tapered-fit-blue-zir01sf55-001.html',
#   'brand': 'Guru',
#   'category': 'Jeans Tapered Fit',
#   'price': '26,90',
#   'size': '48',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/meyer-pantalon-black-zir01sdx4-001.html',
#   'brand': 'Meyer',
#   'category': 'Pantalon',
#   'price': '25,90',
#   'size': '38',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tiger-of-sweden-chino-grey-zir01sk2v-001.html',
#   'brand': 'Tiger of Sweden',
#   'category': 'Chino',
#   'price': '51,80',
#   'size': '48',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tiger-of-sweden-broek-blue-zir01sg8q-001.html',
#   'brand': 'Tiger of Sweden',
#   'category': 'Broek',
#   'price': '33,90',
#   'size': '46',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/pme-legend-broek-blue-zir01s7oa-001.html',
#   'brand': 'PME Legend',
#   'category': 'Broek',
#   'price': '39,90',
#   'size': '29x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gabba-broek-blue-zir01sk9r-001.html',
#   'brand': 'Gabba',
#   'category': 'Broek',
#   'price': '27,40',
#   'size': '30',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/ben-sherman-broek-black-zir01sfw6-001.html',
#   'brand': 'Ben Sherman',
#   'category': 'Broek',
#   'price': '17,90',
#   'size': '42',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/hugo-pantalon-black-zir01sdwy-001.html',
#   'brand': 'HUGO',
#   'category': 'Pantalon',
#   'price': '31,90',
#   'size': '35',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/oscar-jacobson-broek-blue-zir01s77f-001.html',
#   'brand': 'Oscar Jacobson',
#   'category': 'Pantalon',
#   'price': '20,90',
#   'size': '54',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/garcia-straight-leg-jeans-blue-zir01sl31-001.html',
#   'brand': 'Garcia',
#   'category': 'Straight leg jeans',
#   'price': '15,90',
#   'size': '32x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/nn07-broek-black-zir01sbka-001.html',
#   'brand': 'NN07',
#   'category': 'Broek',
#   'price': '37,90',
#   'size': '34x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/filippa-k-broek-blue-zir01sbeh-001.html',
#   'brand': 'Filippa K',
#   'category': 'Broek',
#   'price': '37,90',
#   'size': '52',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/woodbird-broek-grey-zir01se5c-001.html',
#   'brand': 'Woodbird',
#   'category': 'Broek',
#   'price': '21,90',
#   'size': '29',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/levis-straight-leg-jeans-blue-zir01sjnk-001.html',
#   'brand': "Levi's®",
#   'category': 'Straight leg jeans',
#   'price': '20,90',
#   'size': '34x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-slim-fit-jeans-blue-zir01sgrc-001.html',
#   'brand': 'Jack & Jones',
#   'category': 'Slim fit jeans',
#   'price': '17,90',
#   'size': '29x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/manuel-ritz-chino-brown-zir01slyr-001.html',
#   'brand': 'Manuel Ritz',
#   'category': 'Chino',
#   'price': '25,90',
#   'size': '33',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/brax-broek-green-zir01sdxy-001.html',
#   'brand': 'BRAX',
#   'category': 'Broek',
#   'price': '27,90',
#   'size': '36x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gerry-weber-broek-black-zir01s5mj-001.html',
#   'brand': 'Gerry Weber',
#   'category': 'Broek',
#   'price': '20,90',
#   'size': '42',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-broek-beige-zir01s674-001.html',
#   'brand': 'Jack & Jones',
#   'category': 'Broek',
#   'price': '15,90',
#   'size': '32x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/filippa-k-chino-black-zir01sgmk-001.html',
#   'brand': 'Filippa K',
#   'category': 'Chino',
#   'price': '31,90',
#   'size': 'S',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/boss-chino-grey-zir01scjd-001.html',
#   'brand': 'BOSS',
#   'category': 'Chino',
#   'price': '28,90',
#   'size': '52',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/brax-broek-green-zir01sfaa-001.html',
#   'brand': 'BRAX',
#   'category': 'Broek',
#   'price': '25,90',
#   'size': '48x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/mustang-slim-fit-jeans-blue-zir01sk3s-001.html',
#   'brand': 'Mustang',
#   'category': 'Slim fit jeans',
#   'price': '25,20',
#   'size': '29x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/cos-broek-beige-zir01sci3-001.html',
#   'brand': 'COS',
#   'category': 'Broek',
#   'price': '18,90',
#   'size': '50',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/calvin-klein-slim-fit-jeans-blue-zir01t0g3-001.html',
#   'brand': 'Calvin Klein',
#   'category': 'Slim fit jeans',
#   'price': '27,20',
#   'size': '34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/meyer-broek-brown-zir01skro-001.html',
#   'brand': 'Meyer',
#   'category': 'Broek',
#   'price': '22,90',
#   'size': '46',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/trussardi-broek-grey-zir01s9h7-001.html',
#   'brand': 'Trussardi',
#   'category': 'Broek',
#   'price': '36,90',
#   'size': '36x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tom-tailor-broek-beige-zir01siba-001.html',
#   'brand': 'TOM TAILOR',
#   'category': 'Broek',
#   'price': '16,90',
#   'size': '36',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tiger-of-sweden-chino-blue-zir01sc54-001.html',
#   'brand': 'Tiger of Sweden',
#   'category': 'Chino',
#   'price': '38,90',
#   'size': '54',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/brax-broek-brown-zir01sdin-001.html',
#   'brand': 'BRAX',
#   'category': 'Broek',
#   'price': '27,90',
#   'size': '34x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/hilfiger-denim-chino-brown-zir01sb64-001.html',
#   'brand': 'Hilfiger Denim',
#   'category': 'Chino',
#   'price': '18,90',
#   'size': '31',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/drykorn-broek-beige-zir01sk5b-001.html',
#   'brand': 'DRYKORN',
#   'category': 'Broek',
#   'price': '16,40',
#   'size': '36x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/napapijri-broek-grey-zir01sde9-001.html',
#   'brand': 'Napapijri',
#   'category': 'Broek',
#   'price': '23,90',
#   'size': '36',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/brax-slim-fit-jeans-blue-zir01sdea-001.html',
#   'brand': 'BRAX',
#   'category': 'Slim fit jeans',
#   'price': '27,90',
#   'size': '28',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/meyer-shorts-blue-zir01sdix-001.html',
#   'brand': 'Meyer',
#   'category': 'Shorts',
#   'price': '26,90',
#   'size': '46x30',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/olymp-level-five-overhemd-blue-zir01saq9-001.html',
#   'brand': 'OLYMP Level Five',
#   'category': 'Overhemd',
#   'price': '17,90',
#   'size': '38',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/nn07-straight-leg-jeans-blue-zir01scry-001.html',
#   'brand': 'NN07',
#   'category': 'Straight leg jeans',
#   'price': '37,90',
#   'size': '29x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/mac-jeans-relaxed-fit-jeans-beige-zir01sct9-001.html',
#   'brand': 'MAC Jeans',
#   'category': 'Relaxed fit jeans',
#   'price': '25,90',
#   'size': '40x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/timberland-overhemd-blue-zir01sm7m-001.html',
#   'brand': 'Timberland',
#   'category': 'Overhemd',
#   'price': '15,90',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/boss-overhemd-black-zir01sjdw-001.html',
#   'brand': 'BOSS',
#   'category': 'Overhemd',
#   'price': '30,40',
#   'size': '42',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/replay-straight-leg-jeans-blue-zir01sg2n-001.html',
#   'brand': 'Replay',
#   'category': 'Straight leg jeans',
#   'price': '61,90',
#   'size': '36',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/adidas-originals-shorts-black-zir01sktu-001.html',
#   'brand': 'adidas Originals',
#   'category': 'Shorts',
#   'price': '13,40',
#   'size': 'S',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tommy-jeans-chino-pink-zir01t5ud-001.html',
#   'brand': 'Tommy Jeans',
#   'category': 'Chino',
#   'price': '16,10',
#   'size': '32x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/ralph-ralph-lauren-jeansshort-blue-zir01t5w8-001.html',
#   'brand': 'RALPH Ralph Lauren',
#   'category': 'Jeansshort',
#   'price': '13,90',
#   'size': '28',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gap-shorts-grey-zir01ska9-001.html',
#   'brand': 'GAP',
#   'category': 'Shorts',
#   'price': '13,40',
#   'size': '28',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/ben-sherman-broek-grey-zir01t5d8-001.html',
#   'brand': 'Ben Sherman',
#   'category': 'Broek',
#   'price': '19,80',
#   'size': '36',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/timberland-shorts-green-zir01siqp-001.html',
#   'brand': 'Timberland',
#   'category': 'Cargobroek',
#   'price': '23,90',
#   'size': '32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/quiksilver-shorts-grey-zir01t4rj-001.html',
#   'brand': 'Quiksilver',
#   'category': 'Shorts',
#   'price': '12,50',
#   'size': 'M',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-shorts-beige-zir01sg96-001.html',
#   'brand': 'Jack & Jones',
#   'category': 'Shorts',
#   'price': '16,90',
#   'size': 'S',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/moods-of-norway-shorts-beige-zir01skap-001.html',
#   'brand': 'Moods of Norway',
#   'category': 'Shorts',
#   'price': '24,40',
#   'size': '50',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/schoeffel-shorts-red-zir01slbi-001.html',
#   'brand': 'Schöffel',
#   'category': 'Shorts',
#   'price': '33,10',
#   'size': '48',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/pierre-cardin-shorts-beige-zir01siyv-001.html',
#   'brand': 'Pierre Cardin',
#   'category': 'Shorts',
#   'price': '21,10',
#   'size': '36',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/buena-vista-jeansshort-blue-zir01siz7-001.html',
#   'brand': 'Buena Vista',
#   'category': 'Jeansshort',
#   'price': '14,30',
#   'size': 'XS',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/adidas-originals-shorts-blue-zir01sen1-001.html',
#   'brand': 'adidas Originals',
#   'category': 'Shorts',
#   'price': '15,90',
#   'size': 'XL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/lerros-shorts-blue-zir01sk4x-001.html',
#   'brand': 'LERROS',
#   'category': 'Shorts',
#   'price': '23,70',
#   'size': '33',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/ben-sherman-shorts-grey-zir01rzfp-001.html',
#   'brand': 'Ben Sherman',
#   'category': 'Shorts',
#   'price': '15,90',
#   'size': '38',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gardeur-broek-grey-zir01s7wp-001.html',
#   'brand': 'Gardeur',
#   'category': 'Broek',
#   'price': '20,90',
#   'size': '40',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/boss-chino-brown-zir01sc8b-001.html',
#   'brand': 'BOSS',
#   'category': 'Chino',
#   'price': '30,90',
#   'size': '50',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/pierre-cardin-broek-black-zir01sf6t-001.html',
#   'brand': 'Pierre Cardin',
#   'category': 'Broek',
#   'price': '25,90',
#   'size': 'XXL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/wrangler-broek-black-zir01sj8j-001.html',
#   'brand': 'Wrangler',
#   'category': 'Broek',
#   'price': '24,30',
#   'size': '29x30',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tiger-of-sweden-pantalon-brown-zir01sg0e-001.html',
#   'brand': 'Tiger of Sweden',
#   'category': 'Pantalon',
#   'price': '37,90',
#   'size': '46',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/mac-jeans-straight-leg-jeans-blue-zir01sgu0-001.html',
#   'brand': 'MAC Jeans',
#   'category': 'Straight leg jeans',
#   'price': '20,90',
#   'size': '46',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gardeur-broek-beige-zir01sj2d-001.html',
#   'brand': 'Gardeur',
#   'category': 'Broek',
#   'price': '20,70',
#   'size': '33x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/brax-broek-beige-zir01s62w-001.html',
#   'brand': 'BRAX',
#   'category': 'Broek',
#   'price': '23,90',
#   'size': '25',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/soliver-straight-leg-jeans-blue-zir01t04a-001.html',
#   'brand': 's.Oliver',
#   'category': 'Straight leg jeans',
#   'price': '12,30',
#   'size': '31x30',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/hugo-broek-black-zir01sh7j-001.html',
#   'brand': 'HUGO',
#   'category': 'Broek',
#   'price': '31,90',
#   'size': '48',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/ben-sherman-broek-grey-zir01s56c-001.html',
#   'brand': 'Ben Sherman',
#   'category': 'Broek',
#   'price': '19,90',
#   'size': '44',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gardeur-chino-brown-zir01sj5k-001.html',
#   'brand': 'Gardeur',
#   'category': 'Chino',
#   'price': '20,70',
#   'size': '34x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/pierre-cardin-broek-beige-zir01rza0-001.html',
#   'brand': 'Pierre Cardin',
#   'category': 'Broek',
#   'price': '24,90',
#   'size': '36',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/brax-straight-leg-jeans-grey-zir01s9fa-001.html',
#   'brand': 'BRAX',
#   'category': 'Straight leg jeans',
#   'price': '22,90',
#   'size': '46',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/g-star-slim-fit-jeans-blue-zir01slcf-001.html',
#   'brand': 'G-Star',
#   'category': 'Slim fit jeans',
#   'price': '17,90',
#   'size': '30x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/pierre-balmain-broek-grey-zir01rzat-001.html',
#   'brand': 'Pierre Balmain',
#   'category': 'Broek',
#   'price': '76,90',
#   'size': '36x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tommy-hilfiger-broek-blue-zir01sio5-001.html',
#   'brand': 'Tommy Hilfiger',
#   'category': 'Broek',
#   'price': '26,90',
#   'size': '48',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/levis-straight-leg-jeans-blue-zir01shoy-001.html',
#   'brand': "Levi's®",
#   'category': 'Straight leg jeans',
#   'price': '28,90',
#   'size': '29x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/bugatti-chino-brown-zir01sk7r-001.html',
#   'brand': 'Bugatti',
#   'category': 'Chino',
#   'price': '24,10',
#   'size': '33x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gabba-slim-fit-jeans-blue-zir01s9lt-001.html',
#   'brand': 'Gabba',
#   'category': 'Slim fit jeans',
#   'price': '25,90',
#   'size': '32x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-straight-leg-jeans-blue-zir01t58d-001.html',
#   'brand': 'Jack & Jones',
#   'category': 'Straight leg jeans',
#   'price': '16,10',
#   'size': '28x30',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gap-chino-beige-zir01scau-001.html',
#   'brand': 'GAP',
#   'category': 'Chino',
#   'price': '15,90',
#   'size': '36x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/marc-opolo-broek-green-zir01sjjk-001.html',
#   'brand': "Marc O'Polo",
#   'category': 'Broek',
#   'price': '12,50',
#   'size': '48',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gant-straight-leg-jeans-black-zir01scus-001.html',
#   'brand': 'GANT',
#   'category': 'Straight leg jeans',
#   'price': '22,90',
#   'size': '33x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/next-overhemd-grey-zir01sew6-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '18,90',
#   'size': 'XL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/marks-and-spencer-overhemd-blue-zir01sf3b-001.html',
#   'brand': 'Marks & Spencer',
#   'category': 'Overhemd',
#   'price': '19,90',
#   'size': '43',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/pierre-cardin-overhemd-blue-zir01sbkb-001.html',
#   'brand': 'Pierre Cardin',
#   'category': 'Overhemd',
#   'price': '19,90',
#   'size': 'XL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/farah-overhemd-orange-zir01scg4-001.html',
#   'brand': 'Farah',
#   'category': 'Overhemd',
#   'price': '20,90',
#   'size': 'M',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/one-green-elephant-relaxed-fit-jeans-blue-zir01sjik-001.html',
#   'brand': 'One Green Elephant',
#   'category': 'Relaxed fit jeans',
#   'price': '13,50',
#   'size': '33',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/marc-opolo-overhemd-pink-zir01sj6a-001.html',
#   'brand': "Marc O'Polo",
#   'category': 'Overhemd',
#   'price': '12,60',
#   'size': 'XXL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gant-overhemd-grey-zir01sktl-001.html',
#   'brand': 'GANT',
#   'category': 'Overhemd',
#   'price': '27,40',
#   'size': 'XL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/samsoee-samsoee-overhemd-blue-zir01shi9-001.html',
#   'brand': 'Samsøe Samsøe',
#   'category': 'Overhemd',
#   'price': '20,90',
#   'size': 'XL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/next-overhemd-purple-zir01t05i-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '12,00',
#   'size': '43',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/next-overhemd-red-zir01sjf9-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '12,30',
#   'size': '43',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/calvin-klein-overhemd-red-zir01sjci-001.html',
#   'brand': 'Calvin Klein',
#   'category': 'Overhemd',
#   'price': '24,60',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/pme-legend-slim-fit-jeans-blue-zir01s7d5-001.html',
#   'brand': 'PME Legend',
#   'category': 'Slim fit jeans',
#   'price': '28,90',
#   'size': '31x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/nn07-broek-blue-zir01sl6g-001.html',
#   'brand': 'NN07',
#   'category': 'Broek',
#   'price': '25,20',
#   'size': '30x32',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/guess-straight-leg-jeans-blue-zir01sea2-001.html',
#   'brand': 'Guess',
#   'category': 'Straight leg jeans',
#   'price': '19,90',
#   'size': '30',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gerry-weber-straight-leg-jeans-black-zir01sjeq-001.html',
#   'brand': 'Gerry Weber',
#   'category': 'Straight leg jeans',
#   'price': '17,90',
#   'size': '48',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gardeur-straight-leg-jeans-grey-zir01sbmf-001.html',
#   'brand': 'Gardeur',
#   'category': 'Straight leg jeans',
#   'price': '20,90',
#   'size': '50',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/hilfiger-denim-straight-leg-jeans-blue-zir01s711-001.html',
#   'brand': 'Hilfiger Denim',
#   'category': 'Straight leg jeans',
#   'price': '27,90',
#   'size': '32x34',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-chino-beige-zir01t4sm-001.html',
#   'brand': 'Jack & Jones',
#   'category': 'Chino',
#   'price': '12,20',
#   'size': '36x36',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/next-overhemd-blue-zir01sm7d-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '15,90',
#   'size': '41',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/olymp-level-five-overhemd-grey-zir01t0lr-001.html',
#   'brand': 'OLYMP Level Five',
#   'category': 'Overhemd',
#   'price': '12,80',
#   'size': '39',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gant-trui-black-zir01q6f4-001.html',
#   'brand': 'GANT',
#   'category': 'Trui',
#   'price': '28,90',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/puma-sweater-met-rits-blue-zir01sj4o-001.html',
#   'brand': 'Puma',
#   'category': 'Sweater met rits',
#   'price': '16,50',
#   'size': '44',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/eterna-zakelijk-overhemd-blue-zir01saxl-001.html',
#   'brand': 'Eterna',
#   'category': 'Zakelijk overhemd',
#   'price': '21,90',
#   'size': '37',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/ea7-emporio-armani-overhemd-blue-zir01sbpz-001.html',
#   'brand': 'EA7 Emporio Armani',
#   'category': 'Overhemd',
#   'price': '43,90',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/olymp-level-five-zakelijk-overhemd-grey-zir01sjv5-001.html',
#   'brand': 'OLYMP Level Five',
#   'category': 'Zakelijk overhemd',
#   'price': '18,00',
#   'size': '42',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/ted-baker-overhemd-white-zir01sbxr-001.html',
#   'brand': 'Ted Baker',
#   'category': 'Overhemd',
#   'price': '32,90',
#   'size': '40',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/replay-overhemd-multi-coloured-zir01s9lg-001.html',
#   'brand': 'Replay',
#   'category': 'Overhemd',
#   'price': '32,90',
#   'size': '39',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/marks-and-spencer-overhemd-beige-zir01sad6-001.html',
#   'brand': 'Marks & Spencer',
#   'category': 'Overhemd',
#   'price': '15,90',
#   'size': '39',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/burton-overhemd-grey-zir01s8rg-001.html',
#   'brand': 'Burton',
#   'category': 'Overhemd',
#   'price': '19,90',
#   'size': 'M',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/soliver-black-label-overhemd-white-zir01sgg7-001.html',
#   'brand': 's.Oliver BLACK LABEL',
#   'category': 'Overhemd',
#   'price': '16,90',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/wrangler-overhemd-brown-zir01sfv3-001.html',
#   'brand': 'Wrangler',
#   'category': 'Overhemd',
#   'price': '39,90',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/wrangler-overhemd-multi-coloured-zir01sjwa-001.html',
#   'brand': 'Wrangler',
#   'category': 'Overhemd',
#   'price': '17,50',
#   'size': 'M',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/eterna-overhemd-blue-zir01skvc-001.html',
#   'brand': 'Eterna',
#   'category': 'Overhemd',
#   'price': '14,10',
#   'size': '43',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/cos-overhemdblouse-blue-zir01sj8c-001.html',
#   'brand': 'COS',
#   'category': 'Overhemd',
#   'price': '21,90',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/pierre-cardin-overhemd-red-zir01sfll-001.html',
#   'brand': 'Pierre Cardin',
#   'category': 'Overhemd',
#   'price': '15,90',
#   'size': 'M',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/makia-overhemd-grey-zir01scrd-001.html',
#   'brand': 'Makia',
#   'category': 'Overhemd',
#   'price': '30,90',
#   'size': 'XXL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/marks-and-spencer-overhemd-purple-zir01sc9f-001.html',
#   'brand': 'Marks & Spencer',
#   'category': 'Overhemd',
#   'price': '20,90',
#   'size': '42',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/next-zakelijk-overhemd-grey-zir01s9ju-001.html',
#   'brand': 'Next',
#   'category': 'Zakelijk overhemd',
#   'price': '16,90',
#   'size': '41',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gant-overhemd-purple-zir01si46-001.html',
#   'brand': 'GANT',
#   'category': 'Overhemd',
#   'price': '25,90',
#   'size': 'M',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/next-overhemd-red-zir01sj37-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '19,40',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-overhemd-red-zir01s98l-001.html',
#   'brand': 'Jack & Jones',
#   'category': 'Overhemd',
#   'price': '15,90',
#   'size': 'S',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/eterna-overhemd-blue-zir01sirt-001.html',
#   'brand': 'Eterna',
#   'category': 'Overhemd',
#   'price': '21,80',
#   'size': '45',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/next-overhemd-blue-zir01sfk6-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '15,90',
#   'size': 'S',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tommy-jeans-overhemd-blue-zir01s7qe-001.html',
#   'brand': 'Tommy Jeans',
#   'category': 'Overhemd',
#   'price': '20,90',
#   'size': 'M',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/olymp-overhemd-green-zir01sbk3-001.html',
#   'brand': 'OLYMP',
#   'category': 'Overhemd',
#   'price': '30,90',
#   'size': '44',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/olymp-level-five-overhemd-white-zir01t4yk-001.html',
#   'brand': 'OLYMP Level Five',
#   'category': 'Overhemd',
#   'price': '13,50',
#   'size': '41',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/christian-berg-overhemd-red-zir01sisg-001.html',
#   'brand': 'Christian Berg',
#   'category': 'Overhemd',
#   'price': '15,90',
#   'size': 'XXL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/marks-and-spencer-overhemd-blue-zir01se25-001.html',
#   'brand': 'Marks & Spencer',
#   'category': 'Overhemd',
#   'price': '20,90',
#   'size': '42',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jcrew-overhemd-green-zir01sek1-001.html',
#   'brand': 'J.CREW',
#   'category': 'Overhemd',
#   'price': '16,90',
#   'size': 'XXL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/next-overhemd-blue-zir01s003-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '16,90',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/sand-copenhagen-overhemd-multi-colored-zir01puku-001.html',
#   'brand': 'Sand Copenhagen',
#   'category': 'Overhemd',
#   'price': '34,90',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/eterna-overhemd-blue-zir01sdxa-001.html',
#   'brand': 'Eterna',
#   'category': 'Overhemd',
#   'price': '19,90',
#   'size': '40',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/eterna-overhemd-blue-zir01se6a-001.html',
#   'brand': 'Eterna',
#   'category': 'Overhemd',
#   'price': '23,90',
#   'size': '50',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/superdry-overhemd-blue-zir01sjxt-001.html',
#   'brand': 'Superdry',
#   'category': 'Overhemd',
#   'price': '19,70',
#   'size': 'S',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tom-tailor-overhemd-green-zir01szxr-001.html',
#   'brand': 'TOM TAILOR',
#   'category': 'Overhemd',
#   'price': '16,40',
#   'size': 'XL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/calvin-klein-jeans-overhemd-grey-zir01t0qt-001.html',
#   'brand': 'Calvin Klein Jeans',
#   'category': 'Overhemd',
#   'price': '20,90',
#   'size': 'XL',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/seidensticker-overhemd-red-zir01t0k5-001.html',
#   'brand': 'Seidensticker',
#   'category': 'Overhemd',
#   'price': '19,70',
#   'size': '42',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-overhemd-black-zir01sj8o-001.html',
#   'brand': 'Jack & Jones',
#   'category': 'Overhemd',
#   'price': '15,60',
#   'size': 'L',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/camel-active-overhemd-green-zir01skog-001.html',
#   'brand': 'camel active',
#   'category': 'Overhemd',
#   'price': '18,40',
#   'size': 'M',
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/gap-overhemd-blue-zir01sjvw-001.html',
#   'brand': 'GAP',
#   'category': 'Overhemd',
#   'price': '18,10',
#   'size': 'S',
#   'delivery time': '3-6'}]

# %%
now = datetime.now()
print(now)
# Out:
# 2022-03-17 11:58:35.170201

# %%
import csv 

with open("product_description_pre_owned.csv", "w", encoding = 'utf-8', newline='') as csv_file: 
    writer = csv.writer(csv_file, delimiter = ";")
    writer.writerow(["url", "brand", "category", "price", "size", "delivery time", "now"])
    now = datetime.now()
    for product in product_attributes: 
        writer.writerow([product['url'], product['brand'], product['category'], product['price'], product['size'], product['delivery time'], now])
print('done!')
# Out:
# done!

# %% [markdown]
# # Zalando scraper | Herenkleding

# %%
# run Zalando Herenkleding
driver.get("https://www.zalando.nl/herenkleding/")
time.sleep(10)
print("done")
# Out:
# done

# %%
# accept button on the website (close pop-ups before proceeding)

driver.find_elements_by_class_name("uc-btn-primary")
# Out:
# /var/folders/p0/r_tdscqn23546rkg5ldzxc180000gn/T/ipykernel_4344/131874113.py:3: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   driver.find_elements_by_class_name("uc-btn-primary")
# [<selenium.webdriver.remote.webelement.WebElement (session="8990e103ed78c7ca7026179af61ce835", element="50821f3e-79b5-4459-8f3c-c17c7163a327")>]

# %%
# Create a function to collect all page urls
base_url = "https://www.zalando.nl/herenkleding/?p="
counter = 1

# Now create the function
def generate_page_urls(base_url, num_pages):
    page_urls = []
    
    for counter in range (1, num_pages + 1):
        full_url = base_url + str(counter) + "&order=activation_date"
        page_urls.append(full_url)
    
    return page_urls

# %%
page_urls = generate_page_urls(base_url, 2) 

generate_page_urls("https://www.zalando.nl/herenkleding/?p=", 20)
# Out:
# ['https://www.zalando.nl/herenkleding/?p=1&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=2&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=3&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=4&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=5&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=6&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=7&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=8&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=9&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=10&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=11&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=12&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=13&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=14&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=15&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=16&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=17&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=18&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=19&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=20&order=activation_date']

# %%
## cadeaubon is geen product 

from bs4 import BeautifulSoup
res = driver.page_source.encode('utf-8')
soup = BeautifulSoup(res, "html.parser")

# Create a function to collect the product_urls
def create_product_urls(page_urls):
    product_urls = []
    cnt=1
    for page_url in page_urls:
        cnt+=1
        driver.get(page_url)
        time.sleep(5)
        res = driver.page_source.encode('utf-8')
        soup = BeautifulSoup(res, "html.parser")
        #f=open('website_'+str(cnt)+'.html', 'w', encoding='utf-8')
        #f.write(res.text)
        #f.close()
        products = soup.find_all("div", class_= "DT5BTM w8MdNG cYylcv QylWsg _75qWlu iOzucJ JT3_zV DvypSJ")       
        print(len(products))
        sleep(1)

        for product in products:
            try:
                product_url = product.find("a").attrs["href"]
                print(product_url)
                product_urls.append(product_url)
            except:
                print("dit is geen product")
                
    return product_urls

# %%
product_urls = create_product_urls(page_urls)
# https://www.zalando.nl/soliver-vest-dark-blue-so222q0r4-k11.html
# https://www.zalando.nl/guess-slim-fit-jeans-blau-gu122g0gx-k11.html
# https://www.zalando.nl/defacto-trainingsbroek-anthracite-dez22e0d7-q12.html
# https://www.zalando.nl/matinique-shorts-rich-beige-m6022f027-b11.html
# https://www.zalando.nl/jack-and-jones-shorts-faded-denim-ja222f0uz-k11.html
# https://www.zalando.nl/jack-and-jones-shorts-drizzle-ja222f0uz-c11.html
# https://www.zalando.nl/napapijri-morgex-fleece-trui-violet-chinese-na622s075-i11.html
# https://www.zalando.nl/fetish-design-overhemd-schwarz-fev22d000-q11.html
# https://www.zalando.nl/forsberg-shorts-schwarz-fou22f003-q11.html
# https://www.zalando.nl/jack-and-jones-vest-maritime-blue-ja222q16a-k11.html
# https://www.zalando.nl/napapijri-morgex-hoodie-sand-prairie-na622s076-b11.html
# https://www.zalando.nl/weekday-ted-sweater-khaki-web22s04q-n11.html
# https://www.zalando.nl/ellesse-tinctoria-oh-hoody-hoodie-black-el922s07g-q11.html
# https://www.zalando.nl/state-of-art-poloshirt-grey-blue-navy-oa422p047-k11.html
# https://www.zalando.nl/state-of-art-poloshirt-jade-lightgrey-oa422p047-m11.html
# https://www.zalando.nl/forsberg-cargobroek-navy-fou22e005-k11.html
# 168

# %%
# scraping information from product pages - Herenkleding
from re import search

def get_product_pages(products):
    product_pages = []
    
    for url in product_urls: 
        res = requests.get(url, headers = user_agent)
        soup = BeautifulSoup(res.text, "html.parser")
        attributes = soup.find_all(class_="DT5BTM VHXqc_ rceRmQ _4NtqZU mIlIve")
        delivery = soup.find(class_="PBR5VH _0xLoFW EJ4MLB")
        prices = soup.find("div", class_="_0xLoFW vSgP6A _7ckuOK")
        size = soup.find("div", class_="_0xLoFW FCIprz")
        
        for attribute in attributes:    
            product = attribute.find("h3", class_="mt1kvu ka2E9k uMhVZi FxZV-M SZKKsK pVrzNP _5Yd-hZ").text
            category = attribute.find("span", class_="EKabf7 R_QwOV").text
            size = size.find("span", class_="_7Cm1F9 ka2E9k uMhVZi dgII7d RYghuO pVrzNP")
            delivery_time = delivery.find("span", class_="u-6V88 ka2E9k uMhVZi dgII7d RYghuO pVrzNP").text
            delivery_time = delivery_time.replace("werkdagen", "")
            delivery_time = delivery_time.replace(" ", "")
            
            substring = " - "            
            if search(substring, category):
                category = category.replace(" -", "")
                # regel die teskt ervoor verwijderd
            else:
                category
                
            try:
                price = prices.find("span", class_="pVrzNP").text
                price = price.replace(u'€\xa0', u' ')
                price = price.replace(" ", "")
            except:
                price = prices.find("span", class_="uqkIZw").text
                price = price.replace(u'€\xa0', u' ')
                price = price.replace(" ", "")
            
            product_pages.append({"url": url,
                                 "brand": product,
                                 "category": category,
                                 "price": price,
                                 "size": size,
                                 "delivery time": delivery_time})
   
    return product_pages
print("done")
# Out:
# done

# %%
product_attributes = get_product_pages(product_urls)

time.sleep(5)

product_attributes
# Out:
# [{'url': 'https://www.zalando.nl/jack-and-jones-slim-fit-jeans-blue-denim-ja222g1td-k11.html',
#   'brand': 'Jack & Jones',
#   'category': 'LIAM SEAL  Jeans Skinny Fit',
#   'price': '69,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tom-tailor-denim-shorts-blue-non-solid-to722f08s-k11.html',
#   'brand': 'TOM TAILOR DENIM',
#   'category': 'Shorts',
#   'price': 'Vanaf39,99',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/tom-tailor-structured-serafino-longsleeve-longsleeve-soft-buttercream-to222o11s-a11.html',
#   'brand': 'TOM TAILOR',
#   'category': 'STRUCTURED SERAFINO LONGSLEEVE Longsleeve',
#   'price': '29,99',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/indicode-jeans-wadim-poloshirt-raven-ij022p00y-q11.html',
#   'brand': 'INDICODE JEANS',
#   'category': 'WADIM Poloshirt',
#   'price': '22,95',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/boss-thinking-t-shirt-print-black-bb122o0ka-q11.html',
#   'brand': 'BOSS',
#   'category': 'THINKING T-shirt print',
#   'price': '39,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/forsberg-cargobroek-anthrazit-fou22e003-q11.html',
#   'brand': 'FORSBERG',
#   'category': 'Cargobroek',
#   'price': '79,95',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/polo-ralph-lauren-overhemd-harbor-island-blue-po222d0t9-k11.html',
#   'brand': 'Polo Ralph Lauren',
#   'category': 'LONG SLEEVE SPORT Overhemd',
#   'price': '129,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-premium-crew-neck-sweater-gray-jam22s054-c11.html',
#   'brand': 'Jack & Jones PREMIUM',
#   'category': 'CREW NECK Sweater',
#   'price': '39,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/john-henric-zakelijk-overhemd-orange-j0w22d014-h11.html',
#   'brand': 'John Henric',
#   'category': 'Zakelijk overhemd',
#   'price': '79,00',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/john-henric-zakelijk-overhemd-blue-j0w22d014-k11.html',
#   'brand': 'John Henric',
#   'category': 'Zakelijk overhemd',
#   'price': '79,00',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/indicode-jeans-wadim-poloshirt-offwhite-ij022p00y-a12.html',
#   'brand': 'INDICODE JEANS',
#   'category': 'WADIM Poloshirt',
#   'price': '22,95',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/fetish-design-overhemd-schwarz-fev22d002-q11.html',
#   'brand': 'Fetish-Design',
#   'category': 'OLIVER Overhemd',
#   'price': '169,98',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/polo-ralph-lauren-overhemd-carmel-pink-po222d0t9-j11.html',
#   'brand': 'Polo Ralph Lauren',
#   'category': 'LONG SLEEVE SPORT Overhemd',
#   'price': '129,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/polo-ralph-lauren-overhemd-andover-heather-po222d0t9-c11.html',
#   'brand': 'Polo Ralph Lauren',
#   'category': 'LONG SLEEVE SPORT Overhemd',
#   'price': '129,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/matinique-zakelijk-overhemd-chambrey-blue-m6022d08x-k11.html',
#   'brand': 'Matinique',
#   'category': 'MARC LUX OXFORD Zakelijk overhemd',
#   'price': '99,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/matinique-matrostol-overhemd-rust-m6022d067-o11.html',
#   'brand': 'Matinique',
#   'category': 'MATROSTOL Overhemd',
#   'price': '79,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/john-henric-overhemd-orange-j0w22d01h-h11.html',
#   'brand': 'John Henric',
#   'category': 'OXFORD Overhemd',
#   'price': '79,00',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/john-henric-overhemd-green-j0w22d01h-m11.html',
#   'brand': 'John Henric',
#   'category': 'OXFORD Overhemd',
#   'price': '79,00',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-premium-jprblafast-resort-overhemd-sky-captain-jam22d0aw-k11.html',
#   'brand': 'Jack & Jones PREMIUM',
#   'category': 'JPRBLAFAST RESORT Overhemd',
#   'price': '29,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/polo-ralph-lauren-overhemd-elite-blue-po222d0tw-k11.html',
#   'brand': 'Polo Ralph Lauren',
#   'category': 'Overhemd',
#   'price': '139,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/polo-ralph-lauren-bear-sweater-empire-yellow-po222s09p-e11.html',
#   'brand': 'Polo Ralph Lauren',
#   'category': 'BEAR  Sweater',
#   'price': '189,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-scale-long-jeansshort-blue-denim-ja222f0u8-k11.html',
#   'brand': 'Jack & Jones',
#   'category': 'SCALE LONG Jeansshort',
#   'price': '49,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/neuw-ray-straight-straight-leg-jeans-washed-clay-nd822g01l-a11.html',
#   'brand': 'Neuw',
#   'category': 'RAY STRAIGHT Straight leg jeans',
#   'price': '119,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/matinique-zakelijk-overhemd-white-m6022d08x-a11.html',
#   'brand': 'Matinique',
#   'category': 'MARC LUX OXFORD Zakelijk overhemd',
#   'price': '99,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-jjirob-original-cj-980-jeans-tapered-fit-blue-denim-ja222g1ra-k11.html',
#   'brand': 'Jack & Jones',
#   'category': 'JJIROB ORIGINAL CJ 980 Jeans Tapered Fit',
#   'price': '49,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/only-and-sons-onsarn-ls-slub-check-shirt-overhemd-black-os322d0mj-q11.html',
#   'brand': 'Only & Sons',
#   'category': 'ONSARN LS SLUB  CHECK SHIRT Overhemd',
#   'price': '29,99',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/edwin-cosmos-pant-straight-leg-jeans-white-ed322e00w-a11.html',
#   'brand': 'Edwin',
#   'category': 'COSMOS PANT Straight leg jeans',
#   'price': '89,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/matinique-shorts-lunar-rock-m6022f027-b12.html',
#   'brand': 'Matinique',
#   'category': 'Trainingsbroek',
#   'price': '69,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/polo-ralph-lauren-hood-long-sleeve-longsleeve-white-beach-bear-po222o0az-a11.html',
#   'brand': 'Polo Ralph Lauren',
#   'category': 'HOOD LONG SLEEVE Hoodie',
#   'price': '109,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/matinique-poloshirt-white-m6022p00w-a11.html',
#   'brand': 'Matinique',
#   'category': 'Poloshirt',
#   'price': '39,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/state-of-art-slim-fit-jeans-beige-plain-oa422g00f-b11.html',
#   'brand': 'State of Art',
#   'category': 'Slim fit jeans',
#   'price': '119,95',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/state-of-art-slim-fit-jeans-moss-green-plain-oa422g00f-n11.html',
#   'brand': 'State of Art',
#   'category': 'Slim fit jeans',
#   'price': '119,95',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/soliver-slim-fit-jeans-dark-blue-so222g0kv-k11.html',
#   'brand': 's.Oliver',
#   'category': 'SUPERSTRETCHIGE Slim fit jeans',
#   'price': '89,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/theory-river-neoteric-korte-jassen-balsam-green-t4022t018-m11.html',
#   'brand': 'Theory',
#   'category': 'RIVER NEOTERIC Korte jassen',
#   'price': '285,00',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/boss-magneton-overhemd-white-bb122d10x-a11.html',
#   'brand': 'BOSS',
#   'category': 'MAGNETON Overhemd',
#   'price': '79,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-jeansshort-blue-denim-ja222f0uy-k11.html',
#   'brand': 'Jack & Jones',
#   'category': 'CHRIS ORIGINAL CJ  Jeansshort',
#   'price': '39,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tiger-of-sweden-sosa-broek-morning-grey-ti522e03v-c12.html',
#   'brand': 'Tiger of Sweden',
#   'category': 'SOSA Broek',
#   'price': '159,95',
#   'size': None,
#   'delivery time': '4-8'},
#  {'url': 'https://www.zalando.nl/boss-sestart-trainingsbroek-light-beige-bb122e0i5-b11.html',
#   'brand': 'BOSS',
#   'category': 'SESTART Trainingsbroek',
#   'price': '99,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/scotch-and-soda-stuart-garment-shorts-lizard-sc322f0bf-n11.html',
#   'brand': 'Scotch & Soda',
#   'category': 'STUART GARMENT Shorts',
#   'price': '79,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/tiger-of-sweden-sosa-broek-dove-grey-ti522e03v-c11.html',
#   'brand': 'Tiger of Sweden',
#   'category': 'SOSA Broek',
#   'price': '159,95',
#   'size': None,
#   'delivery time': '4-8'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-jeansshort-black-denim-ja222f0ux-q11.html',
#   'brand': 'Jack & Jones',
#   'category': 'RICK FOX GE  Jeansshort',
#   'price': '49,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-jorworld-resort-overhemd-cloud-dancer-ja222d21k-a11.html',
#   'brand': 'Jack & Jones',
#   'category': 'JORWORLD RESORT Overhemd',
#   'price': '34,99',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/next-utility-sweater-met-rits-red-nx322q0lc-g11.html',
#   'brand': 'Next',
#   'category': 'UTILITY  Sweater met rits',
#   'price': '82,00',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-cargobroek-blue-denim-ja222e11h-k11.html',
#   'brand': 'Jack & Jones',
#   'category': 'Relaxed fit jeans',
#   'price': '59,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/napapijri-s-trient-longsleeve-black-na622o06e-q11.html',
#   'brand': 'Napapijri',
#   'category': 'S-TRIENT Longsleeve',
#   'price': '59,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/camel-active-straight-leg-jeans-indigo-ca522g096-k11.html',
#   'brand': 'camel active',
#   'category': 'Straight leg jeans',
#   'price': '99,95',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/matinique-overhemd-federal-blue-m6022d09m-k11.html',
#   'brand': 'Matinique',
#   'category': 'Overhemd',
#   'price': '89,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/tommy-jeans-windeaker-zip-off-pant-unisex-cargobroek-black-tob21006c-q11.html',
#   'brand': 'Tommy Jeans',
#   'category': 'WINDEAKER ZIP OFF PANT UNISEX Cargobroek',
#   'price': '129,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-premium-crew-neck-sweater-brown-jam22s054-o12.html',
#   'brand': 'Jack & Jones PREMIUM',
#   'category': 'CREW NECK Sweater',
#   'price': '39,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/boss-zetrust-sweater-dark-blue-bb122s0cq-k11.html',
#   'brand': 'BOSS',
#   'category': 'ZETRUST Sweater',
#   'price': '119,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-jjirick-jjoriginal-jeansshort-hawthorn-rose-ja222f0t9-j11.html',
#   'brand': 'Jack & Jones',
#   'category': 'JJIRICK JJORIGINAL AKM Jeansshort',
#   'price': '24,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-jjirick-jjoriginal-jeansshort-moonbeam-ja222f0t9-a11.html',
#   'brand': 'Jack & Jones',
#   'category': 'JJIRICK JJORIGINAL AKM Jeansshort',
#   'price': '24,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-jjirick-jjoriginal-jeansshort-mellow-yellow-ja222f0t9-e11.html',
#   'brand': 'Jack & Jones',
#   'category': 'JJIRICK JJORIGINAL AKM Jeansshort',
#   'price': '24,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/olymp-overhemd-marine-ol422d167-a12.html',
#   'brand': 'OLYMP',
#   'category': 'Overhemd',
#   'price': '59,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/matinique-overhemd-light-pink-m6022d09w-j11.html',
#   'brand': 'Matinique',
#   'category': 'MATROSTOL CHINA  Overhemd',
#   'price': '79,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/matinique-overhemd-blue-m6022d09w-k11.html',
#   'brand': 'Matinique',
#   'category': 'MATROSTOL CHINA  Overhemd',
#   'price': '79,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/paul-smith-gents-sweater-whiteblue-ps922s01d-a11.html',
#   'brand': 'Paul Smith',
#   'category': 'GENTS Sweater',
#   'price': '255,00',
#   'size': None,
#   'delivery time': '4-8'},
#  {'url': 'https://www.zalando.nl/lacoste-shorts-rose-sy-la222f023-j11.html',
#   'brand': 'Lacoste',
#   'category': 'Shorts',
#   'price': '65,00',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/boss-mabsoot-overhemd-dark-green-bb122d10q-m11.html',
#   'brand': 'BOSS',
#   'category': 'MABSOOT Overhemd',
#   'price': '89,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-slim-fit-jeans-brown-ja222g1ta-o11.html',
#   'brand': 'Jack & Jones',
#   'category': 'Slim fit jeans',
#   'price': '79,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/young-poets-society-cropped-structure-chino-soft-grass-yoj22e00p-m11.html',
#   'brand': 'YOUNG POETS SOCIETY',
#   'category': 'CROPPED STRUCTURE Chino',
#   'price': '132,08',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/sean-john-script-logo-essential-pants-trainingsbroek-light-blue-s5e22e012-k11.html',
#   'brand': 'Sean John',
#   'category': 'SCRIPT LOGO ESSENTIAL PANTS Trainingsbroek',
#   'price': '59,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/soliver-shorts-grey-so222f0kp-c11.html',
#   'brand': 's.Oliver',
#   'category': 'Shorts',
#   'price': '49,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/soliver-shorts-black-so222f0kp-q11.html',
#   'brand': 's.Oliver',
#   'category': 'Shorts',
#   'price': '49,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/soliver-shorts-khaki-oliv-so222f0kp-n11.html',
#   'brand': 's.Oliver',
#   'category': 'Shorts',
#   'price': '49,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/mizuno-athletic-half-pant-korte-broeken-tapestry-m2742e01d-k11.html',
#   'brand': 'Mizuno',
#   'category': 'ATHLETIC HALF PANT Korte broeken',
#   'price': '39,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/icepeak-anzio-outdoorshorts-dark-blue-ic142e04e-k11.html',
#   'brand': 'Icepeak',
#   'category': 'ANZIO Outdoorshorts',
#   'price': '49,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/soliver-shorts-hazelnut-so222f0ko-o11.html',
#   'brand': 's.Oliver',
#   'category': 'Shorts',
#   'price': '39,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/solid-aurelius-shorts-insignia-blue-so422f05o-k11.html',
#   'brand': 'Solid',
#   'category': 'AURELIUS Shorts',
#   'price': '39,95',
#   'size': None,
#   'delivery time': '4-8'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-t-shirt-print-bluefin-ja222o4bw-k12.html',
#   'brand': 'Jack & Jones',
#   'category': 'SUNNY SKULL T-shirt print',
#   'price': '19,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-jjirick-jjoriginal-jeansshort-black-ja222f0t9-q11.html',
#   'brand': 'Jack & Jones',
#   'category': 'JJIRICK JJORIGINAL AKM Jeansshort',
#   'price': '24,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/superdry-shorts-black-su222f0a0-q11.html',
#   'brand': 'Superdry',
#   'category': 'Shorts',
#   'price': '49,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-2-pack-cargobroek-black-ja222e134-q11.html',
#   'brand': 'Jack & Jones',
#   'category': '2 PACK Cargobroek',
#   'price': '69,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/boss-chup-poloshirt-white-bb122p0i1-a11.html',
#   'brand': 'BOSS',
#   'category': 'CHUP Poloshirt',
#   'price': '79,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/ps-paul-smith-t-shirt-print-dark-blue-ps722o06t-k11.html',
#   'brand': 'PS Paul Smith',
#   'category': 'T-shirt print',
#   'price': '79,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/state-of-art-chino-dark-blue-plain-oa422e01d-k11.html',
#   'brand': 'State of Art',
#   'category': 'Chino',
#   'price': '119,95',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/superdry-vintage-embroidered-t-shirt-basic-coral-marl-su222o26l-g11.html',
#   'brand': 'Superdry',
#   'category': 'VINTAGE EMBROIDERED  T-shirt basic',
#   'price': '24,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/maison-labiche-maine-jeansshort-off-white-m7h22f000-a11.html',
#   'brand': 'Maison Labiche',
#   'category': 'MAINE  Jeansshort',
#   'price': '210,00',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/kavu-big-eddy-short-shorts-black-k0s22f001-q11.html',
#   'brand': 'KAVU',
#   'category': 'BIG EDDY  Shorts',
#   'price': '64,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/north-hill-paris-cortot-shorts-beige-n0f22f003-b11.html',
#   'brand': 'NORTH HILL PARIS',
#   'category': 'CORTOT Shorts',
#   'price': '139,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-sweater-navy-blazer-ja222s2e1-k11.html',
#   'brand': 'Jack & Jones',
#   'category': 'Sweater',
#   'price': '39,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/redefined-rebel-melvin-shorts-sandshell-r0622f02d-b11.html',
#   'brand': 'Redefined Rebel',
#   'category': 'MELVIN  Shorts',
#   'price': '29,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/polo-ralph-lauren-repsters-shorts-white-po222f08q-a11.html',
#   'brand': 'Polo Ralph Lauren',
#   'category': 'REPSTERS  Shorts',
#   'price': '109,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/tom-tailor-structured-serafino-longsleeve-longsleeve-sky-captain-blue-to222o11s-k11.html',
#   'brand': 'TOM TAILOR',
#   'category': 'STRUCTURED SERAFINO LONGSLEEVE Longsleeve',
#   'price': '29,99',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/blend-hoodie-dutch-blue-bl522s09s-k11.html',
#   'brand': 'Blend',
#   'category': 'Sweater',
#   'price': '34,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/arket-hoodie-dark-blue-aru22s008-k12.html',
#   'brand': 'ARKET',
#   'category': 'Sweater',
#   'price': '79,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/lindbergh-checked-pleat-shorts-sand-lg522f01c-b11.html',
#   'brand': 'Lindbergh',
#   'category': 'CHECKED PLEAT  Shorts',
#   'price': '39,95',
#   'size': None,
#   'delivery time': '4-8'},
#  {'url': 'https://www.zalando.nl/tom-tailor-denim-overhemd-creme-to722d0q9-a11.html',
#   'brand': 'TOM TAILOR DENIM',
#   'category': 'Overhemd',
#   'price': '39,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/tom-tailor-denim-overhemd-sky-captain-blue-to722d0q9-k11.html',
#   'brand': 'TOM TAILOR DENIM',
#   'category': 'Overhemd',
#   'price': '39,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/massimo-dutti-chino-dark-blue-m3i22e0b8-k11.html',
#   'brand': 'Massimo Dutti',
#   'category': 'Chino',
#   'price': '59,95',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/replay-t-shirt-print-white-re322o0ct-a11.html',
#   'brand': 'Replay',
#   'category': 'HAWAII T-shirt print',
#   'price': '49,00',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/hackett-london-drawstring-trainingsbroek-navy-ht622f01a-k11.html',
#   'brand': 'Hackett London',
#   'category': 'DRAWSTRING Shorts',
#   'price': '129,95',
#   'size': None,
#   'delivery time': '4-8'},
#  {'url': 'https://www.zalando.nl/won-hundred-wayne-relaxed-fit-jeans-coffee-bean-wo322e00x-o11.html',
#   'brand': 'Won Hundred',
#   'category': 'WAYNE Relaxed fit jeans',
#   'price': '174,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/ellesse-rubia-trainingsbroek-green-el922f02b-m11.html',
#   'brand': 'Ellesse',
#   'category': 'RUBIA Shorts',
#   'price': '44,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/boss-sewalk-shorts-dark-blue-bb122f071-k11.html',
#   'brand': 'BOSS',
#   'category': 'SEWALK Shorts',
#   'price': '79,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/boss-sewalk-shorts-dark-green-bb122f071-m11.html',
#   'brand': 'BOSS',
#   'category': 'SEWALK Shorts',
#   'price': '79,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/boss-sewalk-shorts-light-beige-bb122f071-b11.html',
#   'brand': 'BOSS',
#   'category': 'SEWALK Shorts',
#   'price': '79,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/boss-sestart-trainingsbroek-dark-blue-bb122e0i5-k11.html',
#   'brand': 'BOSS',
#   'category': 'SESTART Trainingsbroek',
#   'price': '99,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/tiger-of-sweden-maenard-shorts-black-ti522f01u-q11.html',
#   'brand': 'Tiger of Sweden',
#   'category': 'MAENARD Shorts',
#   'price': '159,95',
#   'size': None,
#   'delivery time': '4-8'},
#  {'url': 'https://www.zalando.nl/jlindeberg-broek-jl-navy-jl122e09q-k11.html',
#   'brand': 'J.LINDEBERG',
#   'category': 'GRANT TRAVEL Broek',
#   'price': '180,00',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jlindeberg-chino-royal-blue-jl122e09h-k11.html',
#   'brand': 'J.LINDEBERG',
#   'category': 'Chino',
#   'price': '180,00',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jlindeberg-stue-korte-broeken-skydiver-jl122f02n-k11.html',
#   'brand': 'J.LINDEBERG',
#   'category': 'STUE  Korte broeken',
#   'price': '140,00',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/theory-city-found-bomberjacks-black-t4022t016-q11.html',
#   'brand': 'Theory',
#   'category': 'CITY FOUND Bomberjacks',
#   'price': '380,00',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/fetish-design-leren-broek-rot-fev22e000-g11.html',
#   'brand': 'Fetish-Design',
#   'category': 'Leren broek',
#   'price': '179,90',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/ricano-leren-broek-schwarz-riv22e006-q11.html',
#   'brand': 'Ricano',
#   'category': 'Leren broek',
#   'price': '259,00',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/matinique-trui-oxford-tan-melange-m6022q031-b11.html',
#   'brand': 'Matinique',
#   'category': 'Trui',
#   'price': '49,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/camel-active-slim-fit-broek-night-blue-ca522e02g-k12.html',
#   'brand': 'camel active',
#   'category': 'SLIM FIT  Broek',
#   'price': '89,95',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/defacto-overhemd-bordeaux-dez22d0h2-g11.html',
#   'brand': 'DeFacto',
#   'category': 'REGULAR FIT  Overhemd',
#   'price': '29,90',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/defacto-regular-fit-overhemd-black-dez22d0h6-q11.html',
#   'brand': 'DeFacto',
#   'category': 'REGULAR FIT Overhemd',
#   'price': '44,90',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/forsberg-cargobroek-schwarz-fou22e000-q11.html',
#   'brand': 'FORSBERG',
#   'category': 'HALPA  Cargobroek',
#   'price': '39,95',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jlindeberg-broek-tiger-brown-jl122e096-o11.html',
#   'brand': 'J.LINDEBERG',
#   'category': 'GORDON 3D  Pantalon',
#   'price': '200,00',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/arket-lucian-half-zip-poloshirt-grey-aru22s00a-c11.html',
#   'brand': 'ARKET',
#   'category': 'Sweater',
#   'price': '79,95',
#   'size': None,
#   'delivery time': '4-8'},
#  {'url': 'https://www.zalando.nl/matinique-trui-black-m6022q031-q11.html',
#   'brand': 'Matinique',
#   'category': 'Trui',
#   'price': '49,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/napapijri-elbas-poloshirt-red-tomato-na622p03h-g11.html',
#   'brand': 'Napapijri',
#   'category': 'ELBAS Poloshirt',
#   'price': '59,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/boss-pokks-poloshirt-navy-bb122p0i3-k11.html',
#   'brand': 'BOSS',
#   'category': 'POKKS Poloshirt',
#   'price': '79,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/boss-tales-t-shirt-basic-open-blue-bb122o0jw-k12.html',
#   'brand': 'BOSS',
#   'category': 'TALES T-shirt basic',
#   'price': '49,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/boss-prime-poloshirt-light-pastel-pink-bb122p0gr-j11.html',
#   'brand': 'BOSS',
#   'category': 'PRIME Poloshirt',
#   'price': '69,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/ps-paul-smith-slim-fit-shirt-poloshirt-white-ps722p02d-a11.html',
#   'brand': 'PS Paul Smith',
#   'category': 'SLIM FIT SHIRT Poloshirt',
#   'price': '89,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/north-hill-paris-korte-jassen-blue-n0f22t00a-k11.html',
#   'brand': 'NORTH HILL PARIS',
#   'category': 'ORSEL JACKET Korte jassen',
#   'price': '339,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/weekday-nano-terry-sweater-black-web22s04r-k11.html',
#   'brand': 'Weekday',
#   'category': 'NANO TERRY Sweater',
#   'price': '40,00',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/good-for-nothing-hoodie-grey-gog22s029-c11.html',
#   'brand': 'Good For Nothing',
#   'category': 'GREY ACID WASH HOOD Sweater',
#   'price': '59,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/drdenim-omar-crease-pants-chino-black-dr122e00g-q11.html',
#   'brand': 'Dr.Denim',
#   'category': 'OMAR CREASE PANTS Chino',
#   'price': '69,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/tom-tailor-denim-cotton-linen-shorts-navy-white-to722f08s-a11.html',
#   'brand': 'TOM TAILOR DENIM',
#   'category': 'Shorts',
#   'price': '39,99',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/fetish-design-leren-broek-dunkelblau-fev22e000-k11.html',
#   'brand': 'Fetish-Design',
#   'category': 'Leren broek',
#   'price': '179,90',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/massimo-dutti-chino-light-grey-m3i22e0b8-c11.html',
#   'brand': 'Massimo Dutti',
#   'category': 'Chino',
#   'price': '59,95',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/fetish-design-lederhemd-california-overhemd-schwarz-fev22d001-q11.html',
#   'brand': 'Fetish-Design',
#   'category': 'LEDERHEMD CALIFORNIA Overhemd',
#   'price': '154,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/allsaints-nippon-overhemd-light-blue-a0q22d0in-k11.html',
#   'brand': 'AllSaints',
#   'category': 'NIPPON Overhemd',
#   'price': '129,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/2blind2c-bomberjacks-navy-2b122t00m-k11.html',
#   'brand': '2Blind2C',
#   'category': 'JESUS  Bomberjacks  navy',
#   'price': '149,00',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/allsaints-opposition-pants-trainingsbroek-black-a0q22e02m-q11.html',
#   'brand': 'AllSaints',
#   'category': 'OPPOSITION PANTS Trainingsbroek',
#   'price': '109,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/jlindeberg-chaze-super-pants-chino-navy-jl122e08u-k11.html',
#   'brand': 'J.LINDEBERG',
#   'category': 'CHAZE SUPER PANTS Chino',
#   'price': '109,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/jlindeberg-broek-blue-indigo-jl122e09o-k11.html',
#   'brand': 'J.LINDEBERG',
#   'category': 'LEO Broek',
#   'price': '180,00',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/polo-ralph-lauren-long-sleeve-sport-overhemd-spring-orange-po222d0k8-h11.html',
#   'brand': 'Polo Ralph Lauren',
#   'category': 'LONG SLEEVE SPORT  Overhemd',
#   'price': '109,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/selected-homme-slhnorman-t-shirt-print-light-blue-se622o0p1-m12.html',
#   'brand': 'Selected Homme',
#   'category': 'SLHNORMAN  T-shirt print',
#   'price': '19,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/finshley-and-harding-overhemd-blau-taupe-fiu22d039-a13.html',
#   'brand': 'FINSHLEY & HARDING',
#   'category': 'Overhemd',
#   'price': '39,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/revolution-casual-shorts-army-re622f01a-n11.html',
#   'brand': 'REVOLUTION',
#   'category': 'CASUAL Shorts',
#   'price': '59,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/levis-contemporary-spijkerjas-naturals-le221004p-e11.html',
#   'brand': "Levi's®",
#   'category': 'CONTEMPORARY Spijkerjas',
#   'price': '129,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/billabong-kinderbord-blue-bi722t025-k11.html',
#   'brand': 'Billabong',
#   'category': 'SURF  Poncho',
#   'price': '65,95',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/032c-selfie-cardigan-unisex-vest-black-03021001n-q11.html',
#   'brand': '032c',
#   'category': 'SELFIE CARDIGAN UNISEX Vest',
#   'price': '375,00',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/lee-relaxed-chino-black-le422e01v-q11.html',
#   'brand': 'Lee',
#   'category': 'RELAXED Chino',
#   'price': '69,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/denim-project-logo-airjet-organic-hoodie-hoodie-deep-depths-deo22s01q-m11.html',
#   'brand': 'Denim Project',
#   'category': 'LOGO AIRJET ORGANIC HOODIE Hoodie',
#   'price': '34,95',
#   'size': None,
#   'delivery time': '1-4'},
#  {'url': 'https://www.zalando.nl/weekday-oversized-2-pack-t-shirt-basic-whitegrey-melange-web22o05o-a11.html',
#   'brand': 'Weekday',
#   'category': 'OVERSIZED 2 PACK T-shirt basic',
#   'price': '30,00',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/polo-ralph-lauren-long-sleeve-sport-overhemd-bluered-multi-po222d0tk-k11.html',
#   'brand': 'Polo Ralph Lauren',
#   'category': 'LONG SLEEVE SPORT Overhemd',
#   'price': '149,95',
#   'size': None,
#   'delivery time': '4-8'},
#  {'url': 'https://www.zalando.nl/wrangler-greensboro-straight-leg-jeans-mid-term-wr122g03w-k17.html',
#   'brand': 'Wrangler',
#   'category': 'GREENSBORO Straight leg jeans',
#   'price': '84,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/boss-seeger-hoodie-silver-bb122s0cy-d11.html',
#   'brand': 'BOSS',
#   'category': 'SEEGER Sweater',
#   'price': '179,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/indicode-jeans-wadim-poloshirt-black-ij022p00y-q12.html',
#   'brand': 'INDICODE JEANS',
#   'category': 'WADIM Poloshirt',
#   'price': '22,95',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/forsberg-granson-hoodie-schwarz-fou22s005-q11.html',
#   'brand': 'FORSBERG',
#   'category': 'GRANSON Sweater',
#   'price': '59,95',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/polo-ralph-lauren-custom-poloshirt-starboard-red-po222p0ih-g11.html',
#   'brand': 'Polo Ralph Lauren',
#   'category': 'CUSTOM Poloshirt',
#   'price': '109,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/bugatti-poloshirt-yellow-bu122p03q-e11.html',
#   'brand': 'Bugatti',
#   'category': 'Poloshirt',
#   'price': '49,95',
#   'size': None,
#   'delivery time': '4-8'},
#  {'url': 'https://www.zalando.nl/soliver-vest-off-white-so222q0r4-a11.html',
#   'brand': 's.Oliver',
#   'category': 'JAS Sweater met rits',
#   'price': '69,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/soliver-pique-poloshirt-light-orange-melan-so222p0cu-h11.html',
#   'brand': 's.Oliver',
#   'category': 'Poloshirt',
#   'price': '35,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/ricano-leren-jas-cognac-braun-riv22t00n-b11.html',
#   'brand': 'Ricano',
#   'category': 'NEVIO R Leren jas',
#   'price': '219,00',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/huf-daytona-jacket-korte-jassen-indigo-h0h22t01v-k11.html',
#   'brand': 'HUF',
#   'category': 'DAYTONA JACKET Korte jassen',
#   'price': '179,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/soliver-vest-dark-blue-so222q0r4-k11.html',
#   'brand': 's.Oliver',
#   'category': 'JAS Sweater met rits',
#   'price': '69,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/guess-slim-fit-jeans-blau-gu122g0gx-k11.html',
#   'brand': 'Guess',
#   'category': 'Slim fit jeans',
#   'price': '110,00',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/defacto-trainingsbroek-anthracite-dez22e0d7-q12.html',
#   'brand': 'DeFacto',
#   'category': 'SLIM FIT  Trainingsbroek',
#   'price': '24,90',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/matinique-shorts-rich-beige-m6022f027-b11.html',
#   'brand': 'Matinique',
#   'category': 'Trainingsbroek',
#   'price': '69,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-shorts-faded-denim-ja222f0uz-k11.html',
#   'brand': 'Jack & Jones',
#   'category': 'FURY AKM Shorts',
#   'price': '49,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-shorts-drizzle-ja222f0uz-c11.html',
#   'brand': 'Jack & Jones',
#   'category': 'FURY AKM Shorts',
#   'price': '49,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/napapijri-morgex-fleece-trui-violet-chinese-na622s075-i11.html',
#   'brand': 'Napapijri',
#   'category': 'MORGEX Fleece trui',
#   'price': '89,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/fetish-design-overhemd-schwarz-fev22d000-q11.html',
#   'brand': 'Fetish-Design',
#   'category': 'Overhemd',
#   'price': '164,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/forsberg-shorts-schwarz-fou22f003-q11.html',
#   'brand': 'FORSBERG',
#   'category': 'Shorts',
#   'price': '34,95',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-vest-maritime-blue-ja222q16a-k11.html',
#   'brand': 'Jack & Jones',
#   'category': 'Vest',
#   'price': '39,99',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/napapijri-morgex-hoodie-sand-prairie-na622s076-b11.html',
#   'brand': 'Napapijri',
#   'category': 'MORGEX Sweater',
#   'price': '99,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/weekday-ted-sweater-khaki-web22s04q-n11.html',
#   'brand': 'Weekday',
#   'category': 'TED Sweater',
#   'price': '35,00',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/ellesse-tinctoria-oh-hoody-hoodie-black-el922s07g-q11.html',
#   'brand': 'Ellesse',
#   'category': 'TINCTORIA OH HOODY Sweater',
#   'price': '59,95',
#   'size': None,
#   'delivery time': '1-2'},
#  {'url': 'https://www.zalando.nl/state-of-art-poloshirt-grey-blue-navy-oa422p047-k11.html',
#   'brand': 'State of Art',
#   'category': 'Poloshirt',
#   'price': '79,95',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/state-of-art-poloshirt-jade-lightgrey-oa422p047-m11.html',
#   'brand': 'State of Art',
#   'category': 'Poloshirt',
#   'price': '79,95',
#   'size': None,
#   'delivery time': '3-6'},
#  {'url': 'https://www.zalando.nl/forsberg-cargobroek-navy-fou22e005-k11.html',
#   'brand': 'FORSBERG',
#   'category': 'BRAXA Cargobroek',
#   'price': '79,95',
#   'size': None,
#   'delivery time': '3-6'}]

# %%
now = datetime.now()
print(now)
# Out:
# 2022-03-17 17:05:58.281940

# %%
# make csv
with open("product_description_herenkleding.csv", "w", encoding = 'utf-8', newline='') as csv_file: 
    writer = csv.writer(csv_file, delimiter = ";")
    writer.writerow(["url", "brand", "category", "price", "size", "delivery time", "now"])
    now = datetime.now()
    for product in product_attributes: 
        writer.writerow([product['url'], product['brand'], product['category'], product['price'], product['size'], product['delivery time'], now])
print('done!')
# Out:
# done!
